# %%
import numpy as np
import pandas as pd
from typing import Union, Tuple, List, Optional
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy import text, desc
from sqlalchemy.exc import NoResultFound, DataError, IntegrityError

# %%
from sqlalchemy import (
    Column,
    ForeignKey,
    Integer,
    String,
    Date,
    DateTime
)
from sqlalchemy.dialects.postgresql import (
    CHAR,
    NUMERIC
)
from sqlalchemy.orm import declarative_base
from sqlalchemy.sql import func


Base = declarative_base()

class Product(Base):
    __tablename__ = 'product'
    product_id = Column(Integer, primary_key=True)
    product_desc = Column(String(50), nullable=False)
    product_usage_type = Column(CHAR(1), nullable=True)
    product_min_weight = Column(NUMERIC(18,2), nullable=False)
    product_max_weight = Column(NUMERIC(18,2), nullable=True)
    product_group = Column(CHAR(10), nullable=True)
    product_type = Column(CHAR(10), nullable=True)


class Customer(Base):
    __tablename__ = 'customer'
    customer_id = Column(Integer, primary_key=True)
    customer_priority = Column(Integer, nullable=False)
    customer_name = Column(String(50), nullable=False)
    customer_group_id = Column(Integer, nullable=False)


class Resource(Base):
    __tablename__ = 'resource'
    resource_id = Column(Integer, primary_key=True)
    resource_desc = Column(String(30), nullable=False)
    wearout_factor = Column(NUMERIC(18,2), nullable=False)
    start_maintenance = Column(Integer, nullable=True)
    end_maintenance = Column(Integer, nullable=True)
    status = Column(CHAR(1), nullable=False)


class Standard_Operation(Base):
    __tablename__ = 'standard_operation'
    operation_id = Column(Integer, autoincrement=True, primary_key=True)
    product_id = Column(Integer, ForeignKey('product.product_id'), nullable=False)
    resource_id = Column(Integer, ForeignKey('resource.resource_id'), nullable=False)
    alternative_pref = Column(Integer)
    standard_op_no = Column(Integer, nullable=False)
    operation_type = Column(CHAR(1), nullable=False)
    standard_time = Column(NUMERIC(18,3), nullable=False)
    yield_percent = Column(NUMERIC(18,3), nullable=False)


class Sales_Orders(Base):
    __tablename__ = 'sales_orders'
    sales_order_id = Column(CHAR(6), primary_key=True)
    customer_id = Column(Integer, ForeignKey('customer.customer_id'), nullable=False)
    product_id = Column(Integer, ForeignKey('product.product_id'), nullable=False)
    so_quantity = Column(NUMERIC(18, 3), nullable=False)
    so_tolerance = Column(NUMERIC(18, 3), nullable=False)
    shipped_quantity = Column(NUMERIC(18, 2), nullable=True)
    so_status = Column(Integer, nullable=False)
    orig_due_date = Column(DateTime, nullable=False)
    so_due_date = Column(DateTime, nullable=False)
    release_date = Column(DateTime, nullable=True)
    ship_to_location = Column(String(50), nullable=True)
    original_from_date = Column(DateTime, nullable=True)

class Product_Link(Base):
    __tablename__ = 'product_link'
    product_link_id = Column(Integer, primary_key=True)
    owner_pruduct = Column(CHAR(40), nullable=False)
    component_product = Column(CHAR(40), nullable=False)
    product_link_ty_id = Column(CHAR(1), nullable=False, default='L')
    operation_id = Column(Integer, nullable=False)

class MRP_Plan(Base):
    __tablename__ = 'mrp_plan'
    id = Column(Integer, autoincrement=True, primary_key=True)
    product_id = Column(Integer, ForeignKey('product.product_id'), nullable=False)
    quantity = Column(Integer, nullable=False)
    weight = Column(NUMERIC(18, 3), nullable=False)
    release_date = Column(DateTime, nullable=False)
    sales_order_id = Column(CHAR(6), ForeignKey('sales_orders.sales_order_id'), nullable=True)

# %%
class DBManager:
    # region inner methods
    def __init__(self):
        self._connect()
        self._recreate_table()
        self.db_session()

    def _connect(self) -> None:
        self.engine = create_engine(
            f"postgresql://kimdaniil:mpsn100%@localhost/scm_k",
            echo=True,
        )

    def _recreate_table(self) -> None:
        Base.metadata.drop_all(self.engine)
        Base.metadata.create_all(self.engine)

    def db_session(self) -> None:
        self.Session = sessionmaker(bind=self.engine)
        self.session = self.Session()

    def close_connection(self) -> None:
        self.engine.dispose()

    def __del__(self) -> None:
        self.close_connection()

    # endregion

# %%
db = DBManager()
# Out:
# 2023-06-08 21:41:11,124 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2023-06-08 21:41:11,125 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-06-08 21:41:11,127 INFO sqlalchemy.engine.Engine select current_schema()
# 2023-06-08 21:41:11,127 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-06-08 21:41:11,129 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2023-06-08 21:41:11,129 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-06-08 21:41:11,130 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:11,132 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,133 INFO sqlalchemy.engine.Engine [generated in 0.00054s] {'table_name': 'product', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,137 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,138 INFO sqlalchemy.engine.Engine [cached since 0.005301s ago] {'table_name': 'customer', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,138 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,139 INFO sqlalchemy.engine.Engine [cached since 0.006461s ago] {'table_name': 'resource', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,139 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,139 INFO sqlalchemy.engine.Engine [cached since 0.00724s ago] {'table_name': 'standard_operation', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,140 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,141 INFO sqlalchemy.engine.Engine [cached since 0.008347s ago] {'table_name': 'sales_orders', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,141 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,142 INFO sqlalchemy.engine.Engine [cached since 0.009469s ago] {'table_name': 'product_link', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,142 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,143 INFO sqlalchemy.engine.Engine [cached since 0.01031s ago] {'table_name': 'mrp_plan', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,143 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:11,143 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:11,144 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,144 INFO sqlalchemy.engine.Engine [cached since 0.01177s ago] {'table_name': 'product', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,145 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,145 INFO sqlalchemy.engine.Engine [cached since 0.01253s ago] {'table_name': 'customer', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,145 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,145 INFO sqlalchemy.engine.Engine [cached since 0.01324s ago] {'table_name': 'resource', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,146 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,146 INFO sqlalchemy.engine.Engine [cached since 0.01393s ago] {'table_name': 'standard_operation', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,147 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,147 INFO sqlalchemy.engine.Engine [cached since 0.01464s ago] {'table_name': 'sales_orders', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,147 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,148 INFO sqlalchemy.engine.Engine [cached since 0.01548s ago] {'table_name': 'product_link', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,151 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:41:11,151 INFO sqlalchemy.engine.Engine [cached since 0.01891s ago] {'table_name': 'mrp_plan', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:41:11,152 INFO sqlalchemy.engine.Engine
# CREATE TABLE product (
# 	product_id SERIAL NOT NULL,
# 	product_desc VARCHAR(50) NOT NULL,
# 	product_usage_type CHAR(1),
# 	product_min_weight NUMERIC(18, 2) NOT NULL,
# 	product_max_weight NUMERIC(18, 2),
# 	product_group CHAR(10),
# 	product_type CHAR(10),
# 	PRIMARY KEY (product_id)
# )
#
#
# 2023-06-08 21:41:11,153 INFO sqlalchemy.engine.Engine [no key 0.00034s] {}
# 2023-06-08 21:41:11,173 INFO sqlalchemy.engine.Engine
# CREATE TABLE customer (
# 	customer_id SERIAL NOT NULL,
# 	customer_priority INTEGER NOT NULL,
# 	customer_name VARCHAR(50) NOT NULL,
# 	customer_group_id INTEGER NOT NULL,
# 	PRIMARY KEY (customer_id)
# )
#
#
# 2023-06-08 21:41:11,173 INFO sqlalchemy.engine.Engine [no key 0.00033s] {}
# 2023-06-08 21:41:11,175 INFO sqlalchemy.engine.Engine
# CREATE TABLE resource (
# 	resource_id SERIAL NOT NULL,
# 	resource_desc VARCHAR(30) NOT NULL,
# 	wearout_factor NUMERIC(18, 2) NOT NULL,
# 	start_maintenance INTEGER,
# 	end_maintenance INTEGER,
# 	status CHAR(1) NOT NULL,
# 	PRIMARY KEY (resource_id)
# )
#
#
# 2023-06-08 21:41:11,176 INFO sqlalchemy.engine.Engine [no key 0.00019s] {}
# 2023-06-08 21:41:11,179 INFO sqlalchemy.engine.Engine
# CREATE TABLE product_link (
# 	product_link_id SERIAL NOT NULL,
# 	owner_pruduct CHAR(40) NOT NULL,
# 	component_product CHAR(40) NOT NULL,
# 	product_link_ty_id CHAR(1) NOT NULL,
# 	operation_id INTEGER NOT NULL,
# 	PRIMARY KEY (product_link_id)
# )
#
#
# 2023-06-08 21:41:11,179 INFO sqlalchemy.engine.Engine [no key 0.00040s] {}
# 2023-06-08 21:41:11,182 INFO sqlalchemy.engine.Engine
# CREATE TABLE standard_operation (
# 	operation_id SERIAL NOT NULL,
# 	product_id INTEGER NOT NULL,
# 	resource_id INTEGER NOT NULL,
# 	alternative_pref INTEGER,
# 	standard_op_no INTEGER NOT NULL,
# 	operation_type CHAR(1) NOT NULL,
# 	standard_time NUMERIC(18, 3) NOT NULL,
# 	yield_percent NUMERIC(18, 3) NOT NULL,
# 	PRIMARY KEY (operation_id),
# 	FOREIGN KEY(product_id) REFERENCES product (product_id),
# 	FOREIGN KEY(resource_id) REFERENCES resource (resource_id)
# )
#
#
# 2023-06-08 21:41:11,182 INFO sqlalchemy.engine.Engine [no key 0.00046s] {}
# 2023-06-08 21:41:11,190 INFO sqlalchemy.engine.Engine
# CREATE TABLE sales_orders (
# 	sales_order_id CHAR(6) NOT NULL,
# 	customer_id INTEGER NOT NULL,
# 	product_id INTEGER NOT NULL,
# 	so_quantity NUMERIC(18, 3) NOT NULL,
# 	so_tolerance NUMERIC(18, 3) NOT NULL,
# 	shipped_quantity NUMERIC(18, 2),
# 	so_status INTEGER NOT NULL,
# 	orig_due_date TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	so_due_date TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	release_date TIMESTAMP WITHOUT TIME ZONE,
# 	ship_to_location VARCHAR(50),
# 	original_from_date TIMESTAMP WITHOUT TIME ZONE,
# 	PRIMARY KEY (sales_order_id),
# 	FOREIGN KEY(customer_id) REFERENCES customer (customer_id),
# 	FOREIGN KEY(product_id) REFERENCES product (product_id)
# )
#
#
# 2023-06-08 21:41:11,191 INFO sqlalchemy.engine.Engine [no key 0.00042s] {}
# 2023-06-08 21:41:11,193 INFO sqlalchemy.engine.Engine
# CREATE TABLE mrp_plan (
# 	id SERIAL NOT NULL,
# 	product_id INTEGER NOT NULL,
# 	quantity INTEGER NOT NULL,
# 	weight NUMERIC(18, 3) NOT NULL,
# 	release_date TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	sales_order_id CHAR(6),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(product_id) REFERENCES product (product_id),
# 	FOREIGN KEY(sales_order_id) REFERENCES sales_orders (sales_order_id)
# )
#
#
# 2023-06-08 21:41:11,193 INFO sqlalchemy.engine.Engine [no key 0.00021s] {}
# 2023-06-08 21:41:11,196 INFO sqlalchemy.engine.Engine COMMIT

# %%
customers = [
    ('MMKI', 2, 1),
    ('Метинвест', 1, 1),
    ('ТМК', 2, 1),
    ('Инпром', 1, 1),
    ('Синара', 3, 1),
    ('АвтоВАЗ', 4, 1),
    ('FIAT', 3, 1),
    ('VAI', 1, 1)
]

customer_db = [Customer(customer_name=customer[0], customer_priority=customer[1], customer_group_id=customer[2]) for customer in customers]

for customer in customer_db:
    db.session.add(customer)

# %%
db.session.commit()
# Out:
# 2023-06-08 21:41:12,933 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:12,935 INFO sqlalchemy.engine.Engine INSERT INTO customer (customer_priority, customer_name, customer_group_id) SELECT p0::INTEGER, p1::VARCHAR, p2::INTEGER FROM (VALUES (%(customer_priority__0)s, %(customer_name__0)s, %(customer_group_id__0)s, 0), (%(customer_priority__1)s, %(customer_ ... 542 characters truncated ... counter) ORDER BY sen_counter RETURNING customer.customer_id, customer.customer_id AS customer_id__1
# 2023-06-08 21:41:12,936 INFO sqlalchemy.engine.Engine [generated in 0.00006s (insertmanyvalues) 1/1 (ordered)] {'customer_group_id__0': 1, 'customer_name__0': 'MMKI', 'customer_priority__0': 2, 'customer_group_id__1': 1, 'customer_name__1': 'Метинвест', 'customer_priority__1': 1, 'customer_group_id__2': 1, 'customer_name__2': 'ТМК', 'customer_priority__2': 2, 'customer_group_id__3': 1, 'customer_name__3': 'Инпром', 'customer_priority__3': 1, 'customer_group_id__4': 1, 'customer_name__4': 'Синара', 'customer_priority__4': 3, 'customer_group_id__5': 1, 'customer_name__5': 'АвтоВАЗ', 'customer_priority__5': 4, 'customer_group_id__6': 1, 'customer_name__6': 'FIAT', 'customer_priority__6': 3, 'customer_group_id__7': 1, 'customer_name__7': 'VAI', 'customer_priority__7': 1}
# 2023-06-08 21:41:12,941 INFO sqlalchemy.engine.Engine COMMIT

# %%
products = [
    ('Г/К Лист', 10),
    ('Г/К Рулон травл', 5),
    ('Г/К Рулон травл дрес', 25),
    ('Г/К Лист травл', 5),
    ('Г/К Лист травл дрес', 5),
    ('Г/К Рулон', 18),
    ('сляб', 0)
]

products_db = [Product(product_desc=product[0], product_min_weight=product[1]) for product in products]

for product in products_db:
    db.session.add(product)

db.session.commit()
# Out:
# 2023-06-08 21:41:13,878 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:13,880 INFO sqlalchemy.engine.Engine INSERT INTO product (product_desc, product_usage_type, product_min_weight, product_max_weight, product_group, product_type) SELECT p0::VARCHAR, p1::VARCHAR, p2::NUMERIC(18, 2), p3::NUMERIC(18, 2), p4::VARCHAR, p5::VARCHAR FROM (VALUES (%(product_desc ... 1069 characters truncated ...  sen_counter) ORDER BY sen_counter RETURNING product.product_id, product.product_id AS product_id__1
# 2023-06-08 21:41:13,880 INFO sqlalchemy.engine.Engine [generated in 0.00006s (insertmanyvalues) 1/1 (ordered)] {'product_min_weight__0': 10, 'product_type__0': None, 'product_desc__0': 'Г/К Лист', 'product_usage_type__0': None, 'product_group__0': None, 'product_max_weight__0': None, 'product_min_weight__1': 5, 'product_type__1': None, 'product_desc__1': 'Г/К Рулон травл', 'product_usage_type__1': None, 'product_group__1': None, 'product_max_weight__1': None, 'product_min_weight__2': 25, 'product_type__2': None, 'product_desc__2': 'Г/К Рулон травл дрес', 'product_usage_type__2': None, 'product_group__2': None, 'product_max_weight__2': None, 'product_min_weight__3': 5, 'product_type__3': None, 'product_desc__3': 'Г/К Лист травл', 'product_usage_type__3': None, 'product_group__3': None, 'product_max_weight__3': None, 'product_min_weight__4': 5, 'product_type__4': None, 'product_desc__4': 'Г/К Лист травл дрес', 'product_usage_type__4': None, 'product_group__4': None, 'product_max_weight__4': None, 'product_min_weight__5': 18, 'product_type__5': None, 'product_desc__5': 'Г/К Рулон', 'product_usage_type__5': None, 'product_group__5': None, 'product_max_weight__5': None, 'product_min_weight__6': 0, 'product_type__6': None, 'product_desc__6': 'сляб', 'product_usage_type__6': None, 'product_group__6': None, 'product_max_weight__6': None}
# 2023-06-08 21:41:13,884 INFO sqlalchemy.engine.Engine COMMIT

# %%
resources = [
    (1, 'Прокатный стан', 1),
    (1, 'Линия упаковки1', 1),
    (1, 'Агрегат резки1', 1),
    (1, 'Агрегат резки2', 1),
    (1, 'Агрегат травления', 1),
    (1, 'Линия дрессировки', 1),
    (1, 'Линия упаковки2', 1)
]

resources_db = [Resource(status=resource[0], resource_desc=resource[1], wearout_factor=resource[2]) for resource in resources]

for resource in resources_db:
    db.session.merge(resource)

db.session.commit()
# Out:
# 2023-06-08 21:41:14,785 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:14,786 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:41:14,787 INFO sqlalchemy.engine.Engine [generated in 0.00056s] {'resource_desc': 'Прокатный стан', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:41:14,790 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:41:14,790 INFO sqlalchemy.engine.Engine [cached since 0.003817s ago] {'resource_desc': 'Линия упаковки1', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:41:14,791 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:41:14,791 INFO sqlalchemy.engine.Engine [cached since 0.004991s ago] {'resource_desc': 'Агрегат резки1', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:41:14,792 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:41:14,792 INFO sqlalchemy.engine.Engine [cached since 0.006036s ago] {'resource_desc': 'Агрегат резки2', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:41:14,793 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:41:14,793 INFO sqlalchemy.engine.Engine [cached since 0.007066s ago] {'resource_desc': 'Агрегат травления', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:41:14,794 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:41:14,794 INFO sqlalchemy.engine.Engine [cached since 0.008091s ago] {'resource_desc': 'Линия дрессировки', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:41:14,795 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:41:14,795 INFO sqlalchemy.engine.Engine [cached since 0.008819s ago] {'resource_desc': 'Линия упаковки2', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:41:14,795 INFO sqlalchemy.engine.Engine COMMIT

# %%
standard_operations = [
    (1, 1, 1, 20, 1, 155, 0.984),
    (2, 5, 1, 30, 1, 150, 1),
    (3, 6, 1, 50, 1, 150, 0.984),
    (4, 5, 1, 30, 1, 150, 1),
    (5, 6, 1, 50, 1, 150, 0.984),
    (6, 1, 1, 20, 1, 155, 0.984),
    (1, 3, 1, 80, 1, 200, 0.984),
    (6, 3, 1, 80, 1, 200, 0.984),
    (6, 2, 1, 90, 1, 180, 1),
    (5, 4, 1, 80, 1, 150, 0.984),
    (5, 7, 1, 90, 1, 200, 1),
    (4, 4, 1, 80, 1, 150, 0.984),
    (4, 7, 1, 90, 1, 200, 1),
]

standard_operations_db = [Standard_Operation(product_id=standard_operation[0],
                                             resource_id=standard_operation[1],
                                             alternative_pref=standard_operation[2],
                                             standard_op_no=standard_operation[3],
                                             operation_type=standard_operation[4],
                                             standard_time=standard_operation[5],
                                             yield_percent=standard_operation[6])
                          for standard_operation in standard_operations]

for standard_operation in standard_operations_db:
    db.session.add(standard_operation)

db.session.commit()
# Out:
# 2023-06-08 21:41:15,845 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:15,847 INFO sqlalchemy.engine.Engine INSERT INTO standard_operation (product_id, resource_id, alternative_pref, standard_op_no, operation_type, standard_time, yield_percent) SELECT p0::INTEGER, p1::INTEGER, p2::INTEGER, p3::INTEGER, p4::VARCHAR, p5::NUMERIC(18, 3), p6::NUMERIC(18, 3) FR ... 2168 characters truncated ... ounter RETURNING standard_operation.operation_id, standard_operation.operation_id AS operation_id__1
# 2023-06-08 21:41:15,848 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/1 (ordered)] {'standard_time__0': 155, 'alternative_pref__0': 1, 'product_id__0': 1, 'yield_percent__0': 0.984, 'resource_id__0': 1, 'operation_type__0': 1, 'standard_op_no__0': 20, 'standard_time__1': 150, 'alternative_pref__1': 1, 'product_id__1': 2, 'yield_percent__1': 1, 'resource_id__1': 5, 'operation_type__1': 1, 'standard_op_no__1': 30, 'standard_time__2': 150, 'alternative_pref__2': 1, 'product_id__2': 3, 'yield_percent__2': 0.984, 'resource_id__2': 6, 'operation_type__2': 1, 'standard_op_no__2': 50, 'standard_time__3': 150, 'alternative_pref__3': 1, 'product_id__3': 4, 'yield_percent__3': 1, 'resource_id__3': 5, 'operation_type__3': 1, 'standard_op_no__3': 30, 'standard_time__4': 150, 'alternative_pref__4': 1, 'product_id__4': 5, 'yield_percent__4': 0.984, 'resource_id__4': 6, 'operation_type__4': 1, 'standard_op_no__4': 50, 'standard_time__5': 155, 'alternative_pref__5': 1, 'product_id__5': 6, 'yield_percent__5': 0.984, 'resource_id__5': 1, 'operation_type__5': 1, 'standard_op_no__5': 20, 'standard_time__6': 200, 'alternative_pref__6': 1, 'product_id__6': 1, 'yield_percent__6': 0.984, 'resource_id__6': 3, 'operation_type__6': 1, 'standard_op_no__6': 80, 'standard_time__7': 200, 'alternative_pref__7': 1, 'product_id__7': 6, 'yield_percent__7': 0.984, 'resource_id__7': 3, 'operation_type__7': 1, 'standard_op_no__7': 80, 'standard_time__8': 180, 'alternative_pref__8': 1, 'product_id__8': 6, 'yield_percent__8': 1, 'resource_id__8': 2, 'operation_type__8': 1, 'standard_op_no__8': 90, 'standard_time__9': 150, 'alternative_pref__9': 1, 'product_id__9': 5, 'yield_percent__9': 0.984, 'resource_id__9': 4, 'operation_type__9': 1, 'standard_op_no__9': 80, 'standard_time__10': 200, 'alternative_pref__10': 1, 'product_id__10': 5, 'yield_percent__10': 1, 'resource_id__10': 7, 'operation_type__10': 1, 'standard_op_no__10': 90, 'standard_time__11': 150, 'alternative_pref__11': 1, 'product_id__11': 4, 'yield_percent__11': 0.984, 'resource_id__11': 4, 'operation_type__11': 1, 'standard_op_no__11': 80, 'standard_time__12': 200, 'alternative_pref__12': 1, 'product_id__12': 4, 'yield_percent__12': 1, 'resource_id__12': 7, 'operation_type__12': 1, 'standard_op_no__12': 90}
# 2023-06-08 21:41:15,851 INFO sqlalchemy.engine.Engine COMMIT

# %%
product_link = [
    (1, "Г/К Лист", "сляб", "L", 20),
    (2, "Г/К Рулон травл", "Г/К Рулон", "L", 30),
    (3, "Г/К Рулон", "сляб", "L", 20),
    (4, "Г/К Рулон травл дрес", "Г/К Рулон травл", "L", 50),
    (5, "Г/К Лист травл дрес", "Г/К Лист травл", "L", 50),
    (6, "Г/К Лист травл", "Г/К Лист", "L", 30),
]

product_link_db = [Product_Link(product_link_id=product_link[0],
                                owner_pruduct=product_link[1],
                                component_product=product_link[2],
                                product_link_ty_id=product_link[3],
                                operation_id=product_link[4])
                     for product_link in product_link]

for product_link in product_link_db:
    db.session.add(product_link)

db.session.commit()
# Out:
# 2023-06-08 21:41:16,685 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:16,698 INFO sqlalchemy.engine.Engine INSERT INTO product_link (product_link_id, owner_pruduct, component_product, product_link_ty_id, operation_id) VALUES (%(product_link_id__0)s, %(owner_pruduct__0)s, %(component_product__0)s, %(product_link_ty_id__0)s, %(operation_id__0)s), (%(product ... 498 characters truncated ... 5)s, %(owner_pruduct__5)s, %(component_product__5)s, %(product_link_ty_id__5)s, %(operation_id__5)s)
# 2023-06-08 21:41:16,705 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/1 (unordered)] {'product_link_ty_id__0': 'L', 'operation_id__0': 20, 'component_product__0': 'сляб', 'product_link_id__0': 1, 'owner_pruduct__0': 'Г/К Лист', 'product_link_ty_id__1': 'L', 'operation_id__1': 30, 'component_product__1': 'Г/К Рулон', 'product_link_id__1': 2, 'owner_pruduct__1': 'Г/К Рулон травл', 'product_link_ty_id__2': 'L', 'operation_id__2': 20, 'component_product__2': 'сляб', 'product_link_id__2': 3, 'owner_pruduct__2': 'Г/К Рулон', 'product_link_ty_id__3': 'L', 'operation_id__3': 50, 'component_product__3': 'Г/К Рулон травл', 'product_link_id__3': 4, 'owner_pruduct__3': 'Г/К Рулон травл дрес', 'product_link_ty_id__4': 'L', 'operation_id__4': 50, 'component_product__4': 'Г/К Лист травл', 'product_link_id__4': 5, 'owner_pruduct__4': 'Г/К Лист травл дрес', 'product_link_ty_id__5': 'L', 'operation_id__5': 30, 'component_product__5': 'Г/К Лист', 'product_link_id__5': 6, 'owner_pruduct__5': 'Г/К Лист травл'}
# 2023-06-08 21:41:16,708 INFO sqlalchemy.engine.Engine COMMIT

# %%
sales_orders = [
    ('SO1001', 1, 1, 1800, 15, 12, 0, '2022-04-11', '2022-04-11'),
    ('SO1002', 2, 4, 1000, 10, 8, 0, '2022-04-17', '2022-04-17'),
    ('SO1003', 3, 3, 1750, 30, 25, 0, '2022-04-23', '2022-04-23'),
    ('SO1004', 4, 4, 6200, 15, 15, 0, '2022-04-30', '2022-04-30'),
    ('SO1005', 5, 2, 1920, 5, 5, 0, '2022-04-26', '2022-04-26'),
    ('SO1006', 6, 3, 2900, 35, 30, 0, '2022-04-10', '2022-04-10'),
    ('SO1007', 7, 1, 3800, 15, 10, 0, '2022-04-04', '2022-04-04'),
    ('SO1008', 8, 6, 2000, 20, 18, 0, '2022-04-12', '2022-04-12'),
]

sales_orders_db = [Sales_Orders(sales_order_id=sales_order[0],
                                customer_id=sales_order[1],
                                product_id=sales_order[2],
                                so_quantity=sales_order[3],
                                so_tolerance=sales_order[4],
                                shipped_quantity=sales_order[5],
                                so_status=sales_order[6],
                                orig_due_date=sales_order[7],
                                so_due_date=sales_order[8])
                        for sales_order in sales_orders]

for sales_order in sales_orders_db:
    db.session.add(sales_order)

db.session.commit()
# Out:
# 2023-06-08 21:41:17,656 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:17,657 INFO sqlalchemy.engine.Engine INSERT INTO sales_orders (sales_order_id, customer_id, product_id, so_quantity, so_tolerance, shipped_quantity, so_status, orig_due_date, so_due_date, release_date, ship_to_location, original_from_date) VALUES (%(sales_order_id__0)s, %(customer_id__0 ... 1962 characters truncated ... e__7)s, %(so_due_date__7)s, %(release_date__7)s, %(ship_to_location__7)s, %(original_from_date__7)s)
# 2023-06-08 21:41:17,657 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/1 (unordered)] {'shipped_quantity__0': 12, 'so_due_date__0': '2022-04-11', 'release_date__0': None, 'so_quantity__0': 1800, 'customer_id__0': 1, 'so_tolerance__0': 15, 'product_id__0': 1, 'sales_order_id__0': 'SO1001', 'so_status__0': 0, 'original_from_date__0': None, 'ship_to_location__0': None, 'orig_due_date__0': '2022-04-11', 'shipped_quantity__1': 8, 'so_due_date__1': '2022-04-17', 'release_date__1': None, 'so_quantity__1': 1000, 'customer_id__1': 2, 'so_tolerance__1': 10, 'product_id__1': 4, 'sales_order_id__1': 'SO1002', 'so_status__1': 0, 'original_from_date__1': None, 'ship_to_location__1': None, 'orig_due_date__1': '2022-04-17', 'shipped_quantity__2': 25, 'so_due_date__2': '2022-04-23', 'release_date__2': None, 'so_quantity__2': 1750, 'customer_id__2': 3, 'so_tolerance__2': 30, 'product_id__2': 3, 'sales_order_id__2': 'SO1003', 'so_status__2': 0, 'original_from_date__2': None, 'ship_to_location__2': None, 'orig_due_date__2': '2022-04-23', 'shipped_quantity__3': 15, 'so_due_date__3': '2022-04-30', 'release_date__3': None, 'so_quantity__3': 6200, 'customer_id__3': 4, 'so_tolerance__3': 15, 'product_id__3': 4, 'sales_order_id__3': 'SO1004', 'so_status__3': 0, 'original_from_date__3': None, 'ship_to_location__3': None, 'orig_due_date__3': '2022-04-30', 'shipped_quantity__4': 5, 'so_due_date__4': '2022-04-26', 'release_date__4': None, 'so_quantity__4': 1920, 'customer_id__4': 5, 'so_tolerance__4': 5, 'product_id__4': 2, 'sales_order_id__4': 'SO1005', 'so_status__4': 0, 'original_from_date__4': None, 'ship_to_location__4': None, 'orig_due_date__4': '2022-04-26', 'shipped_quantity__5': 30, 'so_due_date__5': '2022-04-10', 'release_date__5': None, 'so_quantity__5': 2900, 'customer_id__5': 6, 'so_tolerance__5': 35, 'product_id__5': 3, 'sales_order_id__5': 'SO1006', 'so_status__5': 0, 'original_from_date__5': None, 'ship_to_location__5': None, 'orig_due_date__5': '2022-04-10', 'shipped_quantity__6': 10, 'so_due_date__6': '2022-04-04', 'release_date__6': None, 'so_quantity__6': 3800, 'customer_id__6': 7, 'so_tolerance__6': 15, 'product_id__6': 1, 'sales_order_id__6': 'SO1007', 'so_status__6': 0, 'original_from_date__6': None, 'ship_to_location__6': None, 'orig_due_date__6': '2022-04-04', 'shipped_quantity__7': 18, 'so_due_date__7': '2022-04-12', 'release_date__7': None, 'so_quantity__7': 2000, 'customer_id__7': 8, 'so_tolerance__7': 20, 'product_id__7': 6, 'sales_order_id__7': 'SO1008', 'so_status__7': 0, 'original_from_date__7': None, 'ship_to_location__7': None, 'orig_due_date__7': '2022-04-12'}
# 2023-06-08 21:41:17,659 INFO sqlalchemy.engine.Engine COMMIT

# %%
import datetime

# %%
def balancing(target: int, unit_weight: int, resources) -> int:
    time = (target / resources[0].standard_time) * 60

    if time / 60 > 23:
        time += 60

    return float(time)

# %%
from decimal import Decimal

# %%
def recursive_mrp(product_id: int,
                  unit_weight: float,
                  target: int,
                  release_date: str,
                  quantity: int,
                  sales_order_id: Optional[str],
                  operation_id: int = None) -> None:

    last_record = db.session.query(MRP_Plan)\
        .filter(MRP_Plan.sales_order_id == sales_order_id)\
        .order_by(desc(MRP_Plan.release_date))\
        .first()

    if operation_id is None:
        # Считаем время на упаковку
        if product_id in [1, 6]:
            p, s = 1, 1
        else:
            p, s = 2, 2

        resources = db.session.query(Resource, Standard_Operation.standard_time)\
        .join(Standard_Operation)\
        .filter(Resource.resource_desc == f'Линия упаковки{p}')\
        .all()

        time = balancing(target, unit_weight, resources)

        db.session.add(MRP_Plan(product_id=product_id,
                                quantity=quantity,
                                weight=target,
                                release_date=release_date,
                                sales_order_id=sales_order_id))
        db.session.commit()

        release_date = release_date - datetime.timedelta(minutes=time)


        #Считаем резку
        resources = db.session.query(Resource, Standard_Operation.standard_time)\
        .join(Standard_Operation)\
        .filter(Resource.resource_desc == f'Агрегат резки{s}')\
        .all()

        time = balancing(target, unit_weight, resources)

        unit_weight = unit_weight / Decimal(0.984)
        target = unit_weight * quantity

        db.session.add(MRP_Plan(product_id=product_id,
                                quantity=target / unit_weight,
                                weight=target,
                                release_date=release_date,
                                sales_order_id=sales_order_id))
        db.session.commit()

        release_date = release_date - datetime.timedelta(minutes=time)

    else:
        resources = db.session.query(Standard_Operation)\
            .filter(Standard_Operation.standard_op_no == operation_id)\
            .all()

        unit_weight = unit_weight / resources[0].yield_percent
        target = unit_weight * quantity

        time = balancing(target, unit_weight, resources)

        db.session.add(MRP_Plan(product_id=product_id,
                                quantity=quantity,
                                weight=target,
                                release_date=release_date,
                                sales_order_id=sales_order_id))
        db.session.commit()

        release_date = release_date - datetime.timedelta(minutes=time)


    product_name = db.session.query(Product.product_desc)\
        .filter(Product.product_id == product_id)\
        .one()[0]

    try:
        component = db.session.query(Product_Link)\
            .filter(Product_Link.owner_pruduct == product_name)\
            .one()
    except NoResultFound:
        return None

    product_id = db.session.query(Product.product_id)\
        .filter(Product.product_desc == component.component_product.strip())\
        .one()[0]

    return recursive_mrp(product_id, unit_weight, target, release_date, quantity, sales_order_id, component.operation_id)

# %%
from math import floor

# %%
orders = [a for a in db.session.query(Sales_Orders).join(Customer).order_by(Customer.customer_priority).all()]

for order in orders:
    quantity = floor(order.so_quantity / order.shipped_quantity)
    recursive_mrp(order.product_id, order.shipped_quantity, order.so_quantity, order.so_due_date, quantity, order.sales_order_id)
# Out:
# 2023-06-08 21:41:22,980 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:22,982 INFO sqlalchemy.engine.Engine SELECT sales_orders.sales_order_id AS sales_orders_sales_order_id, sales_orders.customer_id AS sales_orders_customer_id, sales_orders.product_id AS sales_orders_product_id, sales_orders.so_quantity AS sales_orders_so_quantity, sales_orders.so_tolerance AS sales_orders_so_tolerance, sales_orders.shipped_quantity AS sales_orders_shipped_quantity, sales_orders.so_status AS sales_orders_so_status, sales_orders.orig_due_date AS sales_orders_orig_due_date, sales_orders.so_due_date AS sales_orders_so_due_date, sales_orders.release_date AS sales_orders_release_date, sales_orders.ship_to_location AS sales_orders_ship_to_location, sales_orders.original_from_date AS sales_orders_original_from_date
# FROM sales_orders JOIN customer ON customer.customer_id = sales_orders.customer_id ORDER BY customer.customer_priority
# 2023-06-08 21:41:22,983 INFO sqlalchemy.engine.Engine [generated in 0.00067s] {}
# 2023-06-08 21:41:22,986 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:22,987 INFO sqlalchemy.engine.Engine [generated in 0.00049s] {'sales_order_id_1': 'SO1004', 'param_1': 1}
# 2023-06-08 21:41:22,994 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:41:22,996 INFO sqlalchemy.engine.Engine [generated in 0.00202s] {'resource_desc_1': 'Линия упаковки2'}
# 2023-06-08 21:41:23,013 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,014 INFO sqlalchemy.engine.Engine [generated in 0.00149s] {'product_id': 4, 'quantity': 413, 'weight': Decimal('6200.000'), 'release_date': datetime.datetime(2022, 4, 30, 0, 0), 'sales_order_id': 'SO1004'}
# 2023-06-08 21:41:23,025 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,027 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,028 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:41:23,028 INFO sqlalchemy.engine.Engine [cached since 0.03407s ago] {'resource_desc_1': 'Агрегат резки2'}
# 2023-06-08 21:41:23,029 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,029 INFO sqlalchemy.engine.Engine [cached since 0.01695s ago] {'product_id': 4, 'quantity': Decimal('413.0000000000000000000000000'), 'weight': Decimal('6295.731707317073261654195752'), 'release_date': datetime.datetime(2022, 4, 28, 16, 0), 'sales_order_id': 'SO1004'}
# 2023-06-08 21:41:23,030 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,032 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,033 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,034 INFO sqlalchemy.engine.Engine [generated in 0.00041s] {'product_id_1': 4}
# 2023-06-08 21:41:23,037 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,038 INFO sqlalchemy.engine.Engine [generated in 0.00086s] {'owner_pruduct_1': 'Г/К Лист травл'}
# 2023-06-08 21:41:23,039 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:41:23,040 INFO sqlalchemy.engine.Engine [generated in 0.00072s] {'product_desc_1': 'Г/К Лист'}
# 2023-06-08 21:41:23,045 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,045 INFO sqlalchemy.engine.Engine [cached since 0.05879s ago] {'sales_order_id_1': 'SO1004', 'param_1': 1}
# 2023-06-08 21:41:23,046 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:41:23,047 INFO sqlalchemy.engine.Engine [generated in 0.00027s] {'standard_op_no_1': 30}
# 2023-06-08 21:41:23,047 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,048 INFO sqlalchemy.engine.Engine [cached since 0.03517s ago] {'product_id': 1, 'quantity': 413, 'weight': Decimal('6295.731707317073261654195752'), 'release_date': datetime.datetime(2022, 4, 26, 21, 40), 'sales_order_id': 'SO1004'}
# 2023-06-08 21:41:23,048 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,049 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,049 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,050 INFO sqlalchemy.engine.Engine [cached since 0.01643s ago] {'product_id_1': 1}
# 2023-06-08 21:41:23,050 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,050 INFO sqlalchemy.engine.Engine [cached since 0.01377s ago] {'owner_pruduct_1': 'Г/К Лист'}
# 2023-06-08 21:41:23,051 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:41:23,051 INFO sqlalchemy.engine.Engine [cached since 0.01187s ago] {'product_desc_1': 'сляб'}
# 2023-06-08 21:41:23,052 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,052 INFO sqlalchemy.engine.Engine [cached since 0.06579s ago] {'sales_order_id_1': 'SO1004', 'param_1': 1}
# 2023-06-08 21:41:23,053 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:41:23,053 INFO sqlalchemy.engine.Engine [cached since 0.006795s ago] {'standard_op_no_1': 20}
# 2023-06-08 21:41:23,054 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,054 INFO sqlalchemy.engine.Engine [cached since 0.04143s ago] {'product_id': 7, 'quantity': 413, 'weight': Decimal('6398.101328574261444770524137'), 'release_date': datetime.datetime(2022, 4, 25, 2, 41, 42, 439024), 'sales_order_id': 'SO1004'}
# 2023-06-08 21:41:23,055 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,055 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,056 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,056 INFO sqlalchemy.engine.Engine [cached since 0.02269s ago] {'product_id_1': 7}
# 2023-06-08 21:41:23,056 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,057 INFO sqlalchemy.engine.Engine [cached since 0.01997s ago] {'owner_pruduct_1': 'сляб'}
# 2023-06-08 21:41:23,058 INFO sqlalchemy.engine.Engine SELECT sales_orders.sales_order_id AS sales_orders_sales_order_id, sales_orders.customer_id AS sales_orders_customer_id, sales_orders.product_id AS sales_orders_product_id, sales_orders.so_quantity AS sales_orders_so_quantity, sales_orders.so_tolerance AS sales_orders_so_tolerance, sales_orders.shipped_quantity AS sales_orders_shipped_quantity, sales_orders.so_status AS sales_orders_so_status, sales_orders.orig_due_date AS sales_orders_orig_due_date, sales_orders.so_due_date AS sales_orders_so_due_date, sales_orders.release_date AS sales_orders_release_date, sales_orders.ship_to_location AS sales_orders_ship_to_location, sales_orders.original_from_date AS sales_orders_original_from_date
# FROM sales_orders
# WHERE sales_orders.sales_order_id = %(pk_1)s
# 2023-06-08 21:41:23,058 INFO sqlalchemy.engine.Engine [generated in 0.00031s] {'pk_1': 'SO1008'}
# 2023-06-08 21:41:23,060 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,061 INFO sqlalchemy.engine.Engine [cached since 0.07421s ago] {'sales_order_id_1': 'SO1008', 'param_1': 1}
# 2023-06-08 21:41:23,061 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:41:23,062 INFO sqlalchemy.engine.Engine [cached since 0.06786s ago] {'resource_desc_1': 'Линия упаковки1'}
# 2023-06-08 21:41:23,063 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,063 INFO sqlalchemy.engine.Engine [cached since 0.05036s ago] {'product_id': 6, 'quantity': 111, 'weight': Decimal('2000.000'), 'release_date': datetime.datetime(2022, 4, 12, 0, 0), 'sales_order_id': 'SO1008'}
# 2023-06-08 21:41:23,064 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,065 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,065 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:41:23,066 INFO sqlalchemy.engine.Engine [cached since 0.07179s ago] {'resource_desc_1': 'Агрегат резки1'}
# 2023-06-08 21:41:23,067 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,067 INFO sqlalchemy.engine.Engine [cached since 0.05477s ago] {'product_id': 6, 'quantity': Decimal('111.0000000000000000000000000'), 'weight': Decimal('2030.487804878048809811958532'), 'release_date': datetime.datetime(2022, 4, 11, 12, 53, 20), 'sales_order_id': 'SO1008'}
# 2023-06-08 21:41:23,068 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,069 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,069 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,069 INFO sqlalchemy.engine.Engine [cached since 0.0361s ago] {'product_id_1': 6}
# 2023-06-08 21:41:23,070 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,070 INFO sqlalchemy.engine.Engine [cached since 0.03333s ago] {'owner_pruduct_1': 'Г/К Рулон'}
# 2023-06-08 21:41:23,071 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:41:23,071 INFO sqlalchemy.engine.Engine [cached since 0.03137s ago] {'product_desc_1': 'сляб'}
# 2023-06-08 21:41:23,071 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,071 INFO sqlalchemy.engine.Engine [cached since 0.08515s ago] {'sales_order_id_1': 'SO1008', 'param_1': 1}
# 2023-06-08 21:41:23,072 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:41:23,072 INFO sqlalchemy.engine.Engine [cached since 0.02592s ago] {'standard_op_no_1': 20}
# 2023-06-08 21:41:23,073 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,073 INFO sqlalchemy.engine.Engine [cached since 0.06059s ago] {'product_id': 7, 'quantity': 111, 'weight': Decimal('2063.503866745984562817031029'), 'release_date': datetime.datetime(2022, 4, 11, 2, 53, 20), 'sales_order_id': 'SO1008'}
# 2023-06-08 21:41:23,074 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,075 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,075 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,075 INFO sqlalchemy.engine.Engine [cached since 0.04228s ago] {'product_id_1': 7}
# 2023-06-08 21:41:23,076 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,077 INFO sqlalchemy.engine.Engine [cached since 0.03986s ago] {'owner_pruduct_1': 'сляб'}
# 2023-06-08 21:41:23,077 INFO sqlalchemy.engine.Engine SELECT sales_orders.sales_order_id AS sales_orders_sales_order_id, sales_orders.customer_id AS sales_orders_customer_id, sales_orders.product_id AS sales_orders_product_id, sales_orders.so_quantity AS sales_orders_so_quantity, sales_orders.so_tolerance AS sales_orders_so_tolerance, sales_orders.shipped_quantity AS sales_orders_shipped_quantity, sales_orders.so_status AS sales_orders_so_status, sales_orders.orig_due_date AS sales_orders_orig_due_date, sales_orders.so_due_date AS sales_orders_so_due_date, sales_orders.release_date AS sales_orders_release_date, sales_orders.ship_to_location AS sales_orders_ship_to_location, sales_orders.original_from_date AS sales_orders_original_from_date
# FROM sales_orders
# WHERE sales_orders.sales_order_id = %(pk_1)s
# 2023-06-08 21:41:23,077 INFO sqlalchemy.engine.Engine [cached since 0.0192s ago] {'pk_1': 'SO1002'}
# 2023-06-08 21:41:23,078 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,079 INFO sqlalchemy.engine.Engine [cached since 0.09232s ago] {'sales_order_id_1': 'SO1002', 'param_1': 1}
# 2023-06-08 21:41:23,080 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:41:23,080 INFO sqlalchemy.engine.Engine [cached since 0.08601s ago] {'resource_desc_1': 'Линия упаковки2'}
# 2023-06-08 21:41:23,081 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,081 INFO sqlalchemy.engine.Engine [cached since 0.06827s ago] {'product_id': 4, 'quantity': 125, 'weight': Decimal('1000.000'), 'release_date': datetime.datetime(2022, 4, 17, 0, 0), 'sales_order_id': 'SO1002'}
# 2023-06-08 21:41:23,081 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,082 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,082 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:41:23,082 INFO sqlalchemy.engine.Engine [cached since 0.08838s ago] {'resource_desc_1': 'Агрегат резки2'}
# 2023-06-08 21:41:23,083 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,083 INFO sqlalchemy.engine.Engine [cached since 0.07077s ago] {'product_id': 4, 'quantity': Decimal('124.9999999999999999999999999'), 'weight': Decimal('1016.260162601626030936916182'), 'release_date': datetime.datetime(2022, 4, 16, 19, 0), 'sales_order_id': 'SO1002'}
# 2023-06-08 21:41:23,084 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,084 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,085 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,085 INFO sqlalchemy.engine.Engine [cached since 0.05157s ago] {'product_id_1': 4}
# 2023-06-08 21:41:23,085 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,085 INFO sqlalchemy.engine.Engine [cached since 0.04868s ago] {'owner_pruduct_1': 'Г/К Лист травл'}
# 2023-06-08 21:41:23,086 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:41:23,086 INFO sqlalchemy.engine.Engine [cached since 0.04668s ago] {'product_desc_1': 'Г/К Лист'}
# 2023-06-08 21:41:23,087 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,087 INFO sqlalchemy.engine.Engine [cached since 0.1005s ago] {'sales_order_id_1': 'SO1002', 'param_1': 1}
# 2023-06-08 21:41:23,088 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:41:23,088 INFO sqlalchemy.engine.Engine [cached since 0.04146s ago] {'standard_op_no_1': 30}
# 2023-06-08 21:41:23,088 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,088 INFO sqlalchemy.engine.Engine [cached since 0.07599s ago] {'product_id': 1, 'quantity': 125, 'weight': Decimal('1016.260162601626030936916182'), 'release_date': datetime.datetime(2022, 4, 16, 12, 20), 'sales_order_id': 'SO1002'}
# 2023-06-08 21:41:23,089 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,090 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,090 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,090 INFO sqlalchemy.engine.Engine [cached since 0.0569s ago] {'product_id_1': 1}
# 2023-06-08 21:41:23,091 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,091 INFO sqlalchemy.engine.Engine [cached since 0.05401s ago] {'owner_pruduct_1': 'Г/К Лист'}
# 2023-06-08 21:41:23,091 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:41:23,091 INFO sqlalchemy.engine.Engine [cached since 0.05207s ago] {'product_desc_1': 'сляб'}
# 2023-06-08 21:41:23,092 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,092 INFO sqlalchemy.engine.Engine [cached since 0.1058s ago] {'sales_order_id_1': 'SO1002', 'param_1': 1}
# 2023-06-08 21:41:23,093 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:41:23,093 INFO sqlalchemy.engine.Engine [cached since 0.04638s ago] {'standard_op_no_1': 20}
# 2023-06-08 21:41:23,093 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,093 INFO sqlalchemy.engine.Engine [cached since 0.08088s ago] {'product_id': 7, 'quantity': 125, 'weight': Decimal('1032.784718091083364773288803'), 'release_date': datetime.datetime(2022, 4, 16, 5, 33, 29, 756098), 'sales_order_id': 'SO1002'}
# 2023-06-08 21:41:23,094 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,094 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,095 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,095 INFO sqlalchemy.engine.Engine [cached since 0.06169s ago] {'product_id_1': 7}
# 2023-06-08 21:41:23,095 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,096 INFO sqlalchemy.engine.Engine [cached since 0.05886s ago] {'owner_pruduct_1': 'сляб'}
# 2023-06-08 21:41:23,096 INFO sqlalchemy.engine.Engine SELECT sales_orders.sales_order_id AS sales_orders_sales_order_id, sales_orders.customer_id AS sales_orders_customer_id, sales_orders.product_id AS sales_orders_product_id, sales_orders.so_quantity AS sales_orders_so_quantity, sales_orders.so_tolerance AS sales_orders_so_tolerance, sales_orders.shipped_quantity AS sales_orders_shipped_quantity, sales_orders.so_status AS sales_orders_so_status, sales_orders.orig_due_date AS sales_orders_orig_due_date, sales_orders.so_due_date AS sales_orders_so_due_date, sales_orders.release_date AS sales_orders_release_date, sales_orders.ship_to_location AS sales_orders_ship_to_location, sales_orders.original_from_date AS sales_orders_original_from_date
# FROM sales_orders
# WHERE sales_orders.sales_order_id = %(pk_1)s
# 2023-06-08 21:41:23,096 INFO sqlalchemy.engine.Engine [cached since 0.03822s ago] {'pk_1': 'SO1001'}
# 2023-06-08 21:41:23,097 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,097 INFO sqlalchemy.engine.Engine [cached since 0.1106s ago] {'sales_order_id_1': 'SO1001', 'param_1': 1}
# 2023-06-08 21:41:23,098 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:41:23,098 INFO sqlalchemy.engine.Engine [cached since 0.1042s ago] {'resource_desc_1': 'Линия упаковки1'}
# 2023-06-08 21:41:23,099 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,099 INFO sqlalchemy.engine.Engine [cached since 0.08648s ago] {'product_id': 1, 'quantity': 150, 'weight': Decimal('1800.000'), 'release_date': datetime.datetime(2022, 4, 11, 0, 0), 'sales_order_id': 'SO1001'}
# 2023-06-08 21:41:23,099 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,100 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,100 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:41:23,100 INFO sqlalchemy.engine.Engine [cached since 0.1065s ago] {'resource_desc_1': 'Агрегат резки1'}
# 2023-06-08 21:41:23,101 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,101 INFO sqlalchemy.engine.Engine [cached since 0.08866s ago] {'product_id': 1, 'quantity': Decimal('150.0000000000000000000000000'), 'weight': Decimal('1829.268292682926855686449128'), 'release_date': datetime.datetime(2022, 4, 10, 14, 0), 'sales_order_id': 'SO1001'}
# 2023-06-08 21:41:23,102 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,102 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,102 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,102 INFO sqlalchemy.engine.Engine [cached since 0.0692s ago] {'product_id_1': 1}
# 2023-06-08 21:41:23,103 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,103 INFO sqlalchemy.engine.Engine [cached since 0.06627s ago] {'owner_pruduct_1': 'Г/К Лист'}
# 2023-06-08 21:41:23,103 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:41:23,104 INFO sqlalchemy.engine.Engine [cached since 0.06443s ago] {'product_desc_1': 'сляб'}
# 2023-06-08 21:41:23,106 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,109 INFO sqlalchemy.engine.Engine [cached since 0.1225s ago] {'sales_order_id_1': 'SO1001', 'param_1': 1}
# 2023-06-08 21:41:23,113 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:41:23,113 INFO sqlalchemy.engine.Engine [cached since 0.06703s ago] {'standard_op_no_1': 20}
# 2023-06-08 21:41:23,115 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,115 INFO sqlalchemy.engine.Engine [cached since 0.1026s ago] {'product_id': 7, 'quantity': 150, 'weight': Decimal('1859.012492563950056591919846'), 'release_date': datetime.datetime(2022, 4, 10, 5, 0), 'sales_order_id': 'SO1001'}
# 2023-06-08 21:41:23,116 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,117 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,117 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,117 INFO sqlalchemy.engine.Engine [cached since 0.08399s ago] {'product_id_1': 7}
# 2023-06-08 21:41:23,118 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,118 INFO sqlalchemy.engine.Engine [cached since 0.08146s ago] {'owner_pruduct_1': 'сляб'}
# 2023-06-08 21:41:23,119 INFO sqlalchemy.engine.Engine SELECT sales_orders.sales_order_id AS sales_orders_sales_order_id, sales_orders.customer_id AS sales_orders_customer_id, sales_orders.product_id AS sales_orders_product_id, sales_orders.so_quantity AS sales_orders_so_quantity, sales_orders.so_tolerance AS sales_orders_so_tolerance, sales_orders.shipped_quantity AS sales_orders_shipped_quantity, sales_orders.so_status AS sales_orders_so_status, sales_orders.orig_due_date AS sales_orders_orig_due_date, sales_orders.so_due_date AS sales_orders_so_due_date, sales_orders.release_date AS sales_orders_release_date, sales_orders.ship_to_location AS sales_orders_ship_to_location, sales_orders.original_from_date AS sales_orders_original_from_date
# FROM sales_orders
# WHERE sales_orders.sales_order_id = %(pk_1)s
# 2023-06-08 21:41:23,119 INFO sqlalchemy.engine.Engine [cached since 0.06109s ago] {'pk_1': 'SO1003'}
# 2023-06-08 21:41:23,120 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,120 INFO sqlalchemy.engine.Engine [cached since 0.1337s ago] {'sales_order_id_1': 'SO1003', 'param_1': 1}
# 2023-06-08 21:41:23,121 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:41:23,121 INFO sqlalchemy.engine.Engine [cached since 0.1268s ago] {'resource_desc_1': 'Линия упаковки2'}
# 2023-06-08 21:41:23,122 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,122 INFO sqlalchemy.engine.Engine [cached since 0.1094s ago] {'product_id': 3, 'quantity': 70, 'weight': Decimal('1750.000'), 'release_date': datetime.datetime(2022, 4, 23, 0, 0), 'sales_order_id': 'SO1003'}
# 2023-06-08 21:41:23,122 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,123 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,123 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:41:23,124 INFO sqlalchemy.engine.Engine [cached since 0.1296s ago] {'resource_desc_1': 'Агрегат резки2'}
# 2023-06-08 21:41:23,124 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,124 INFO sqlalchemy.engine.Engine [cached since 0.112s ago] {'product_id': 3, 'quantity': Decimal('69.99999999999999999999999999'), 'weight': Decimal('1778.455284552845554139603319'), 'release_date': datetime.datetime(2022, 4, 22, 15, 15), 'sales_order_id': 'SO1003'}
# 2023-06-08 21:41:23,125 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,126 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,126 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,127 INFO sqlalchemy.engine.Engine [cached since 0.0935s ago] {'product_id_1': 3}
# 2023-06-08 21:41:23,127 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,127 INFO sqlalchemy.engine.Engine [cached since 0.09069s ago] {'owner_pruduct_1': 'Г/К Рулон травл дрес'}
# 2023-06-08 21:41:23,128 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:41:23,128 INFO sqlalchemy.engine.Engine [cached since 0.08869s ago] {'product_desc_1': 'Г/К Рулон травл'}
# 2023-06-08 21:41:23,129 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,129 INFO sqlalchemy.engine.Engine [cached since 0.1424s ago] {'sales_order_id_1': 'SO1003', 'param_1': 1}
# 2023-06-08 21:41:23,129 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:41:23,129 INFO sqlalchemy.engine.Engine [cached since 0.083s ago] {'standard_op_no_1': 50}
# 2023-06-08 21:41:23,130 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,130 INFO sqlalchemy.engine.Engine [cached since 0.1178s ago] {'product_id': 2, 'quantity': 70, 'weight': Decimal('1807.373256659395888353255406'), 'release_date': datetime.datetime(2022, 4, 22, 3, 35), 'sales_order_id': 'SO1003'}
# 2023-06-08 21:41:23,131 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,132 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,132 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,132 INFO sqlalchemy.engine.Engine [cached since 0.09934s ago] {'product_id_1': 2}
# 2023-06-08 21:41:23,135 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,135 INFO sqlalchemy.engine.Engine [cached since 0.09832s ago] {'owner_pruduct_1': 'Г/К Рулон травл'}
# 2023-06-08 21:41:23,136 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:41:23,136 INFO sqlalchemy.engine.Engine [cached since 0.09656s ago] {'product_desc_1': 'Г/К Рулон'}
# 2023-06-08 21:41:23,136 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,137 INFO sqlalchemy.engine.Engine [cached since 0.1503s ago] {'sales_order_id_1': 'SO1003', 'param_1': 1}
# ...
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:41:23,224 INFO sqlalchemy.engine.Engine [cached since 0.1779s ago] {'standard_op_no_1': 20}
# 2023-06-08 21:41:23,225 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,225 INFO sqlalchemy.engine.Engine [cached since 0.2125s ago] {'product_id': 7, 'quantity': 384, 'weight': Decimal('1982.946658734880060364714502'), 'release_date': datetime.datetime(2022, 4, 24, 12, 35, 30, 731707), 'sales_order_id': 'SO1005'}
# 2023-06-08 21:41:23,226 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,226 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,227 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,227 INFO sqlalchemy.engine.Engine [cached since 0.1939s ago] {'product_id_1': 7}
# 2023-06-08 21:41:23,228 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,228 INFO sqlalchemy.engine.Engine [cached since 0.1911s ago] {'owner_pruduct_1': 'сляб'}
# 2023-06-08 21:41:23,228 INFO sqlalchemy.engine.Engine SELECT sales_orders.sales_order_id AS sales_orders_sales_order_id, sales_orders.customer_id AS sales_orders_customer_id, sales_orders.product_id AS sales_orders_product_id, sales_orders.so_quantity AS sales_orders_so_quantity, sales_orders.so_tolerance AS sales_orders_so_tolerance, sales_orders.shipped_quantity AS sales_orders_shipped_quantity, sales_orders.so_status AS sales_orders_so_status, sales_orders.orig_due_date AS sales_orders_orig_due_date, sales_orders.so_due_date AS sales_orders_so_due_date, sales_orders.release_date AS sales_orders_release_date, sales_orders.ship_to_location AS sales_orders_ship_to_location, sales_orders.original_from_date AS sales_orders_original_from_date
# FROM sales_orders
# WHERE sales_orders.sales_order_id = %(pk_1)s
# 2023-06-08 21:41:23,229 INFO sqlalchemy.engine.Engine [cached since 0.1705s ago] {'pk_1': 'SO1006'}
# 2023-06-08 21:41:23,229 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,229 INFO sqlalchemy.engine.Engine [cached since 0.243s ago] {'sales_order_id_1': 'SO1006', 'param_1': 1}
# 2023-06-08 21:41:23,230 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:41:23,230 INFO sqlalchemy.engine.Engine [cached since 0.2365s ago] {'resource_desc_1': 'Линия упаковки2'}
# 2023-06-08 21:41:23,231 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,231 INFO sqlalchemy.engine.Engine [cached since 0.2188s ago] {'product_id': 3, 'quantity': 96, 'weight': Decimal('2900.000'), 'release_date': datetime.datetime(2022, 4, 10, 0, 0), 'sales_order_id': 'SO1006'}
# 2023-06-08 21:41:23,232 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,232 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,232 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:41:23,233 INFO sqlalchemy.engine.Engine [cached since 0.2387s ago] {'resource_desc_1': 'Агрегат резки2'}
# 2023-06-08 21:41:23,233 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,234 INFO sqlalchemy.engine.Engine [cached since 0.2211s ago] {'product_id': 3, 'quantity': Decimal('96.00000000000000000000000000'), 'weight': Decimal('2926.829268292682969098318605'), 'release_date': datetime.datetime(2022, 4, 9, 9, 30), 'sales_order_id': 'SO1006'}
# 2023-06-08 21:41:23,234 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,235 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,235 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,235 INFO sqlalchemy.engine.Engine [cached since 0.2019s ago] {'product_id_1': 3}
# 2023-06-08 21:41:23,236 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,236 INFO sqlalchemy.engine.Engine [cached since 0.1991s ago] {'owner_pruduct_1': 'Г/К Рулон травл дрес'}
# 2023-06-08 21:41:23,236 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:41:23,236 INFO sqlalchemy.engine.Engine [cached since 0.197s ago] {'product_desc_1': 'Г/К Рулон травл'}
# 2023-06-08 21:41:23,237 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,237 INFO sqlalchemy.engine.Engine [cached since 0.2507s ago] {'sales_order_id_1': 'SO1006', 'param_1': 1}
# 2023-06-08 21:41:23,238 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:41:23,238 INFO sqlalchemy.engine.Engine [cached since 0.1913s ago] {'standard_op_no_1': 50}
# 2023-06-08 21:41:23,238 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,238 INFO sqlalchemy.engine.Engine [cached since 0.2259s ago] {'product_id': 2, 'quantity': 96, 'weight': Decimal('2974.419988102320090547071754'), 'release_date': datetime.datetime(2022, 4, 8, 14, 10), 'sales_order_id': 'SO1006'}
# 2023-06-08 21:41:23,239 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,240 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,240 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,240 INFO sqlalchemy.engine.Engine [cached since 0.2068s ago] {'product_id_1': 2}
# 2023-06-08 21:41:23,241 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,241 INFO sqlalchemy.engine.Engine [cached since 0.2047s ago] {'owner_pruduct_1': 'Г/К Рулон травл'}
# 2023-06-08 21:41:23,242 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:41:23,243 INFO sqlalchemy.engine.Engine [cached since 0.2032s ago] {'product_desc_1': 'Г/К Рулон'}
# 2023-06-08 21:41:23,243 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,243 INFO sqlalchemy.engine.Engine [cached since 0.257s ago] {'sales_order_id_1': 'SO1006', 'param_1': 1}
# 2023-06-08 21:41:23,244 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:41:23,244 INFO sqlalchemy.engine.Engine [cached since 0.1979s ago] {'standard_op_no_1': 30}
# 2023-06-08 21:41:23,245 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,245 INFO sqlalchemy.engine.Engine [cached since 0.2324s ago] {'product_id': 6, 'quantity': 96, 'weight': Decimal('2974.419988102320090547071754'), 'release_date': datetime.datetime(2022, 4, 7, 18, 20, 13, 920286), 'sales_order_id': 'SO1006'}
# 2023-06-08 21:41:23,245 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,246 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,246 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,246 INFO sqlalchemy.engine.Engine [cached since 0.2134s ago] {'product_id_1': 6}
# 2023-06-08 21:41:23,247 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,247 INFO sqlalchemy.engine.Engine [cached since 0.2106s ago] {'owner_pruduct_1': 'Г/К Рулон'}
# 2023-06-08 21:41:23,248 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:41:23,248 INFO sqlalchemy.engine.Engine [cached since 0.2086s ago] {'product_desc_1': 'сляб'}
# 2023-06-08 21:41:23,248 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:41:23,249 INFO sqlalchemy.engine.Engine [cached since 0.2624s ago] {'sales_order_id_1': 'SO1006', 'param_1': 1}
# 2023-06-08 21:41:23,249 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:41:23,249 INFO sqlalchemy.engine.Engine [cached since 0.203s ago] {'standard_op_no_1': 20}
# 2023-06-08 21:41:23,250 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:41:23,250 INFO sqlalchemy.engine.Engine [cached since 0.2376s ago] {'product_id': 7, 'quantity': 96, 'weight': Decimal('3022.784540754390335921820888'), 'release_date': datetime.datetime(2022, 4, 6, 22, 30, 27, 840572), 'sales_order_id': 'SO1006'}
# 2023-06-08 21:41:23,251 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:41:23,252 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:41:23,252 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:41:23,252 INFO sqlalchemy.engine.Engine [cached since 0.2193s ago] {'product_id_1': 7}
# 2023-06-08 21:41:23,253 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:41:23,253 INFO sqlalchemy.engine.Engine [cached since 0.2164s ago] {'owner_pruduct_1': 'сляб'}
