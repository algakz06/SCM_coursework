# %%
import numpy as np
import pandas as pd
from typing import Union, Tuple, List, Optional
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy import text, desc
from sqlalchemy.exc import NoResultFound, DataError, IntegrityError

# %%
from sqlalchemy import (
    Column,
    ForeignKey,
    Integer,
    String,
    Date,
    DateTime
)
from sqlalchemy.dialects.postgresql import (
    CHAR,
    NUMERIC
)
from sqlalchemy.orm import declarative_base
from sqlalchemy.sql import func


Base = declarative_base()

class Product(Base):
    __tablename__ = 'product'
    product_id = Column(Integer, primary_key=True)
    product_desc = Column(String(50), nullable=False)
    product_usage_type = Column(CHAR(1), nullable=True)
    product_min_weight = Column(NUMERIC(18,2), nullable=False)
    product_max_weight = Column(NUMERIC(18,2), nullable=True)
    product_group = Column(CHAR(10), nullable=True)
    product_type = Column(CHAR(10), nullable=True)


class Customer(Base):
    __tablename__ = 'customer'
    customer_id = Column(Integer, primary_key=True)
    customer_priority = Column(Integer, nullable=False)
    customer_name = Column(String(50), nullable=False)
    customer_group_id = Column(Integer, nullable=False)


class Resource(Base):
    __tablename__ = 'resource'
    resource_id = Column(Integer, primary_key=True)
    resource_desc = Column(String(30), nullable=False)
    wearout_factor = Column(NUMERIC(18,2), nullable=False)
    start_maintenance = Column(Integer, nullable=True)
    end_maintenance = Column(Integer, nullable=True)
    status = Column(CHAR(1), nullable=False)


class Standard_Operation(Base):
    __tablename__ = 'standard_operation'
    operation_id = Column(Integer, autoincrement=True, primary_key=True)
    product_id = Column(Integer, ForeignKey('product.product_id'), nullable=False)
    resource_id = Column(Integer, ForeignKey('resource.resource_id'), nullable=False)
    alternative_pref = Column(Integer)
    standard_op_no = Column(Integer, nullable=False)
    operation_type = Column(CHAR(1), nullable=False)
    standard_time = Column(NUMERIC(18,3), nullable=False)
    yield_percent = Column(NUMERIC(18,3), nullable=False)


class Sales_Orders(Base):
    __tablename__ = 'sales_orders'
    sales_order_id = Column(CHAR(6), primary_key=True)
    customer_id = Column(Integer, ForeignKey('customer.customer_id'), nullable=False)
    product_id = Column(Integer, ForeignKey('product.product_id'), nullable=False)
    so_quantity = Column(NUMERIC(18, 3), nullable=False)
    so_tolerance = Column(NUMERIC(18, 3), nullable=False)
    shipped_quantity = Column(NUMERIC(18, 2), nullable=True)
    so_status = Column(Integer, nullable=False)
    orig_due_date = Column(DateTime, nullable=False)
    so_due_date = Column(DateTime, nullable=False)
    release_date = Column(DateTime, nullable=True)
    ship_to_location = Column(String(50), nullable=True)
    original_from_date = Column(DateTime, nullable=True)

class Product_Link(Base):
    __tablename__ = 'product_link'
    product_link_id = Column(Integer, primary_key=True)
    owner_pruduct = Column(CHAR(40), nullable=False)
    component_product = Column(CHAR(40), nullable=False)
    product_link_ty_id = Column(CHAR(1), nullable=False, default='L')
    operation_id = Column(Integer, nullable=False)

class MRP_Plan(Base):
    __tablename__ = 'mrp_plan'
    id = Column(Integer, autoincrement=True, primary_key=True)
    product_id = Column(Integer, ForeignKey('product.product_id'), nullable=False)
    quantity = Column(Integer, nullable=False)
    weight = Column(NUMERIC(18, 3), nullable=False)
    release_date = Column(DateTime, nullable=False)
    sales_order_id = Column(CHAR(6), ForeignKey('sales_orders.sales_order_id'), nullable=True)

# %%
class DBManager:
    # region inner methods
    def __init__(self):
        self._connect()
        self._recreate_table()
        self.db_session()

    def _connect(self) -> None:
        self.engine = create_engine(
            f"postgresql://kimdaniil:mpsn100%@localhost/scm",
            echo=True,
        )

    def _recreate_table(self) -> None:
        Base.metadata.drop_all(self.engine)
        Base.metadata.create_all(self.engine)

    def db_session(self) -> None:
        self.Session = sessionmaker(bind=self.engine)
        self.session = self.Session()

    def close_connection(self) -> None:
        self.engine.dispose()

    def __del__(self) -> None:
        self.close_connection()

    # endregion

# %%
db = DBManager()
# Out:
# 2023-06-08 21:06:28,413 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2023-06-08 21:06:28,414 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-06-08 21:06:28,415 INFO sqlalchemy.engine.Engine select current_schema()
# 2023-06-08 21:06:28,415 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-06-08 21:06:28,415 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2023-06-08 21:06:28,415 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-06-08 21:06:28,416 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:28,418 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,418 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {'table_name': 'product', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,420 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,420 INFO sqlalchemy.engine.Engine [cached since 0.002126s ago] {'table_name': 'customer', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,420 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,420 INFO sqlalchemy.engine.Engine [cached since 0.002769s ago] {'table_name': 'resource', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,421 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,421 INFO sqlalchemy.engine.Engine [cached since 0.003422s ago] {'table_name': 'standard_operation', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,422 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,422 INFO sqlalchemy.engine.Engine [cached since 0.004066s ago] {'table_name': 'sales_orders', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,422 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,422 INFO sqlalchemy.engine.Engine [cached since 0.004643s ago] {'table_name': 'product_link', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,423 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,423 INFO sqlalchemy.engine.Engine [cached since 0.005243s ago] {'table_name': 'mrp_plan', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,423 INFO sqlalchemy.engine.Engine
# DROP TABLE mrp_plan
# 2023-06-08 21:06:28,424 INFO sqlalchemy.engine.Engine [no key 0.00016s] {}
# 2023-06-08 21:06:28,426 INFO sqlalchemy.engine.Engine
# DROP TABLE sales_orders
# 2023-06-08 21:06:28,426 INFO sqlalchemy.engine.Engine [no key 0.00032s] {}
# 2023-06-08 21:06:28,428 INFO sqlalchemy.engine.Engine
# DROP TABLE standard_operation
# 2023-06-08 21:06:28,428 INFO sqlalchemy.engine.Engine [no key 0.00062s] {}
# 2023-06-08 21:06:28,430 INFO sqlalchemy.engine.Engine
# DROP TABLE product_link
# 2023-06-08 21:06:28,430 INFO sqlalchemy.engine.Engine [no key 0.00025s] {}
# 2023-06-08 21:06:28,431 INFO sqlalchemy.engine.Engine
# DROP TABLE resource
# 2023-06-08 21:06:28,432 INFO sqlalchemy.engine.Engine [no key 0.00044s] {}
# 2023-06-08 21:06:28,432 INFO sqlalchemy.engine.Engine
# DROP TABLE customer
# 2023-06-08 21:06:28,433 INFO sqlalchemy.engine.Engine [no key 0.00018s] {}
# 2023-06-08 21:06:28,434 INFO sqlalchemy.engine.Engine
# DROP TABLE product
# 2023-06-08 21:06:28,434 INFO sqlalchemy.engine.Engine [no key 0.00019s] {}
# 2023-06-08 21:06:28,435 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:28,439 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:28,439 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,439 INFO sqlalchemy.engine.Engine [cached since 0.02141s ago] {'table_name': 'product', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,440 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,440 INFO sqlalchemy.engine.Engine [cached since 0.02227s ago] {'table_name': 'customer', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,440 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,441 INFO sqlalchemy.engine.Engine [cached since 0.02294s ago] {'table_name': 'resource', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,441 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,442 INFO sqlalchemy.engine.Engine [cached since 0.02396s ago] {'table_name': 'standard_operation', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,442 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,443 INFO sqlalchemy.engine.Engine [cached since 0.02495s ago] {'table_name': 'sales_orders', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,443 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,443 INFO sqlalchemy.engine.Engine [cached since 0.02574s ago] {'table_name': 'product_link', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,444 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2023-06-08 21:06:28,444 INFO sqlalchemy.engine.Engine [cached since 0.02656s ago] {'table_name': 'mrp_plan', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2023-06-08 21:06:28,445 INFO sqlalchemy.engine.Engine
# CREATE TABLE product (
# 	product_id SERIAL NOT NULL,
# 	product_desc VARCHAR(50) NOT NULL,
# 	product_usage_type CHAR(1),
# 	product_min_weight NUMERIC(18, 2) NOT NULL,
# 	product_max_weight NUMERIC(18, 2),
# 	product_group CHAR(10),
# 	product_type CHAR(10),
# 	PRIMARY KEY (product_id)
# )
#
#
# 2023-06-08 21:06:28,446 INFO sqlalchemy.engine.Engine [no key 0.00067s] {}
# 2023-06-08 21:06:28,449 INFO sqlalchemy.engine.Engine
# CREATE TABLE customer (
# 	customer_id SERIAL NOT NULL,
# 	customer_priority INTEGER NOT NULL,
# 	customer_name VARCHAR(50) NOT NULL,
# 	customer_group_id INTEGER NOT NULL,
# 	PRIMARY KEY (customer_id)
# )
#
#
# 2023-06-08 21:06:28,449 INFO sqlalchemy.engine.Engine [no key 0.00023s] {}
# 2023-06-08 21:06:28,451 INFO sqlalchemy.engine.Engine
# CREATE TABLE resource (
# 	resource_id SERIAL NOT NULL,
# 	resource_desc VARCHAR(30) NOT NULL,
# 	wearout_factor NUMERIC(18, 2) NOT NULL,
# 	start_maintenance INTEGER,
# 	end_maintenance INTEGER,
# 	status CHAR(1) NOT NULL,
# 	PRIMARY KEY (resource_id)
# )
#
#
# 2023-06-08 21:06:28,452 INFO sqlalchemy.engine.Engine [no key 0.00019s] {}
# 2023-06-08 21:06:28,454 INFO sqlalchemy.engine.Engine
# CREATE TABLE product_link (
# 	product_link_id SERIAL NOT NULL,
# 	owner_pruduct CHAR(40) NOT NULL,
# 	component_product CHAR(40) NOT NULL,
# 	product_link_ty_id CHAR(1) NOT NULL,
# 	operation_id INTEGER NOT NULL,
# 	PRIMARY KEY (product_link_id)
# )
#
#
# 2023-06-08 21:06:28,454 INFO sqlalchemy.engine.Engine [no key 0.00022s] {}
# 2023-06-08 21:06:28,456 INFO sqlalchemy.engine.Engine
# CREATE TABLE standard_operation (
# 	operation_id SERIAL NOT NULL,
# 	product_id INTEGER NOT NULL,
# 	resource_id INTEGER NOT NULL,
# 	alternative_pref INTEGER,
# 	standard_op_no INTEGER NOT NULL,
# 	operation_type CHAR(1) NOT NULL,
# 	standard_time NUMERIC(18, 3) NOT NULL,
# 	yield_percent NUMERIC(18, 3) NOT NULL,
# 	PRIMARY KEY (operation_id),
# 	FOREIGN KEY(product_id) REFERENCES product (product_id),
# 	FOREIGN KEY(resource_id) REFERENCES resource (resource_id)
# )
#
#
# 2023-06-08 21:06:28,456 INFO sqlalchemy.engine.Engine [no key 0.00032s] {}
# 2023-06-08 21:06:28,463 INFO sqlalchemy.engine.Engine
# CREATE TABLE sales_orders (
# 	sales_order_id CHAR(6) NOT NULL,
# 	customer_id INTEGER NOT NULL,
# 	product_id INTEGER NOT NULL,
# 	so_quantity NUMERIC(18, 3) NOT NULL,
# 	so_tolerance NUMERIC(18, 3) NOT NULL,
# 	shipped_quantity NUMERIC(18, 2),
# 	so_status INTEGER NOT NULL,
# 	orig_due_date TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	so_due_date TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	release_date TIMESTAMP WITHOUT TIME ZONE,
# 	ship_to_location VARCHAR(50),
# 	original_from_date TIMESTAMP WITHOUT TIME ZONE,
# 	PRIMARY KEY (sales_order_id),
# 	FOREIGN KEY(customer_id) REFERENCES customer (customer_id),
# 	FOREIGN KEY(product_id) REFERENCES product (product_id)
# )
#
#
# 2023-06-08 21:06:28,463 INFO sqlalchemy.engine.Engine [no key 0.00033s] {}
# 2023-06-08 21:06:28,465 INFO sqlalchemy.engine.Engine
# CREATE TABLE mrp_plan (
# 	id SERIAL NOT NULL,
# 	product_id INTEGER NOT NULL,
# 	quantity INTEGER NOT NULL,
# 	weight NUMERIC(18, 3) NOT NULL,
# 	release_date TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	sales_order_id CHAR(6),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(product_id) REFERENCES product (product_id),
# 	FOREIGN KEY(sales_order_id) REFERENCES sales_orders (sales_order_id)
# )
#
#
# 2023-06-08 21:06:28,466 INFO sqlalchemy.engine.Engine [no key 0.00026s] {}
# 2023-06-08 21:06:28,468 INFO sqlalchemy.engine.Engine COMMIT

# %%
customers = [
    ('TangSteel', 2, 1),
    ('МетПром', 1, 1),
    ('ТМК', 2, 1),
    ('Иркут', 1, 1),
    ('СМ', 3, 1),
    ('АвтоВАЗ', 4, 1),
    ('SAIC Motor', 3, 1),
    ('FAW Group', 1, 1)
]

customer_db = [Customer(customer_name=customer[0], customer_priority=customer[1], customer_group_id=customer[2]) for customer in customers]

for customer in customer_db:
    db.session.add(customer)

# %%
db.session.commit()
# Out:
# 2023-06-08 21:06:30,127 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:30,128 INFO sqlalchemy.engine.Engine INSERT INTO customer (customer_priority, customer_name, customer_group_id) SELECT p0::INTEGER, p1::VARCHAR, p2::INTEGER FROM (VALUES (%(customer_priority__0)s, %(customer_name__0)s, %(customer_group_id__0)s, 0), (%(customer_priority__1)s, %(customer_ ... 542 characters truncated ... counter) ORDER BY sen_counter RETURNING customer.customer_id, customer.customer_id AS customer_id__1
# 2023-06-08 21:06:30,129 INFO sqlalchemy.engine.Engine [generated in 0.00008s (insertmanyvalues) 1/1 (ordered)] {'customer_priority__0': 2, 'customer_name__0': 'TangSteel', 'customer_group_id__0': 1, 'customer_priority__1': 1, 'customer_name__1': 'МетПром', 'customer_group_id__1': 1, 'customer_priority__2': 2, 'customer_name__2': 'ТМК', 'customer_group_id__2': 1, 'customer_priority__3': 1, 'customer_name__3': 'Иркут', 'customer_group_id__3': 1, 'customer_priority__4': 3, 'customer_name__4': 'СМ', 'customer_group_id__4': 1, 'customer_priority__5': 4, 'customer_name__5': 'АвтоВАЗ', 'customer_group_id__5': 1, 'customer_priority__6': 3, 'customer_name__6': 'SAIC Motor', 'customer_group_id__6': 1, 'customer_priority__7': 1, 'customer_name__7': 'FAW Group', 'customer_group_id__7': 1}
# 2023-06-08 21:06:30,134 INFO sqlalchemy.engine.Engine COMMIT

# %%
products = [
    ('Г/К Лист', 10),
    ('Г/К Рулон травл', 5),
    ('Г/К Рулон травл дрес', 25),
    ('Г/К Лист травл', 5),
    ('Г/К Лист травл дрес', 5),
    ('Г/К Рулон', 18),
    ('сляб', 0)
]

products_db = [Product(product_desc=product[0], product_min_weight=product[1]) for product in products]

for product in products_db:
    db.session.add(product)

db.session.commit()
# Out:
# 2023-06-08 21:06:31,024 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:31,035 INFO sqlalchemy.engine.Engine INSERT INTO product (product_desc, product_usage_type, product_min_weight, product_max_weight, product_group, product_type) SELECT p0::VARCHAR, p1::VARCHAR, p2::NUMERIC(18, 2), p3::NUMERIC(18, 2), p4::VARCHAR, p5::VARCHAR FROM (VALUES (%(product_desc ... 1069 characters truncated ...  sen_counter) ORDER BY sen_counter RETURNING product.product_id, product.product_id AS product_id__1
# 2023-06-08 21:06:31,042 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/1 (ordered)] {'product_desc__0': 'Г/К Лист', 'product_usage_type__0': None, 'product_max_weight__0': None, 'product_type__0': None, 'product_group__0': None, 'product_min_weight__0': 10, 'product_desc__1': 'Г/К Рулон травл', 'product_usage_type__1': None, 'product_max_weight__1': None, 'product_type__1': None, 'product_group__1': None, 'product_min_weight__1': 5, 'product_desc__2': 'Г/К Рулон травл дрес', 'product_usage_type__2': None, 'product_max_weight__2': None, 'product_type__2': None, 'product_group__2': None, 'product_min_weight__2': 25, 'product_desc__3': 'Г/К Лист травл', 'product_usage_type__3': None, 'product_max_weight__3': None, 'product_type__3': None, 'product_group__3': None, 'product_min_weight__3': 5, 'product_desc__4': 'Г/К Лист травл дрес', 'product_usage_type__4': None, 'product_max_weight__4': None, 'product_type__4': None, 'product_group__4': None, 'product_min_weight__4': 5, 'product_desc__5': 'Г/К Рулон', 'product_usage_type__5': None, 'product_max_weight__5': None, 'product_type__5': None, 'product_group__5': None, 'product_min_weight__5': 18, 'product_desc__6': 'сляб', 'product_usage_type__6': None, 'product_max_weight__6': None, 'product_type__6': None, 'product_group__6': None, 'product_min_weight__6': 0}
# 2023-06-08 21:06:31,054 INFO sqlalchemy.engine.Engine COMMIT

# %%
resources = [
    (1, 'Прокатный стан', 1),
    (1, 'Линия упаковки1', 1),
    (1, 'Агрегат резки1', 1),
    (1, 'Агрегат резки2', 1),
    (1, 'Агрегат травления', 1),
    (1, 'Линия дрессировки', 1),
    (1, 'Линия упаковки2', 1)
]

resources_db = [Resource(status=resource[0], resource_desc=resource[1], wearout_factor=resource[2]) for resource in resources]

for resource in resources_db:
    db.session.merge(resource)

db.session.commit()
# Out:
# 2023-06-08 21:06:32,022 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:32,023 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:06:32,024 INFO sqlalchemy.engine.Engine [generated in 0.00080s] {'resource_desc': 'Прокатный стан', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:06:32,027 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:06:32,027 INFO sqlalchemy.engine.Engine [cached since 0.003597s ago] {'resource_desc': 'Линия упаковки1', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:06:32,028 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:06:32,028 INFO sqlalchemy.engine.Engine [cached since 0.005123s ago] {'resource_desc': 'Агрегат резки1', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:06:32,029 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:06:32,030 INFO sqlalchemy.engine.Engine [cached since 0.006339s ago] {'resource_desc': 'Агрегат резки2', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:06:32,030 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:06:32,031 INFO sqlalchemy.engine.Engine [cached since 0.007471s ago] {'resource_desc': 'Агрегат травления', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:06:32,032 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:06:32,032 INFO sqlalchemy.engine.Engine [cached since 0.008412s ago] {'resource_desc': 'Линия дрессировки', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:06:32,032 INFO sqlalchemy.engine.Engine INSERT INTO resource (resource_desc, wearout_factor, start_maintenance, end_maintenance, status) VALUES (%(resource_desc)s, %(wearout_factor)s, %(start_maintenance)s, %(end_maintenance)s, %(status)s) RETURNING resource.resource_id
# 2023-06-08 21:06:32,032 INFO sqlalchemy.engine.Engine [cached since 0.009092s ago] {'resource_desc': 'Линия упаковки2', 'wearout_factor': 1, 'start_maintenance': None, 'end_maintenance': None, 'status': 1}
# 2023-06-08 21:06:32,033 INFO sqlalchemy.engine.Engine COMMIT

# %%
standard_operations = [
    (1, 1, 1, 20, 1, 155, 0.984),
    (2, 5, 1, 30, 1, 150, 1),
    (3, 6, 1, 50, 1, 150, 0.984),
    (4, 5, 1, 30, 1, 150, 1),
    (5, 6, 1, 50, 1, 150, 0.984),
    (6, 1, 1, 20, 1, 155, 0.984),
    (1, 3, 1, 80, 1, 200, 0.984),
    (6, 3, 1, 80, 1, 200, 0.984),
    (6, 2, 1, 90, 1, 180, 1),
    (5, 4, 1, 80, 1, 150, 0.984),
    (5, 7, 1, 90, 1, 200, 1),
    (4, 4, 1, 80, 1, 150, 0.984),
    (4, 7, 1, 90, 1, 200, 1),
]

standard_operations_db = [Standard_Operation(product_id=standard_operation[0],
                                             resource_id=standard_operation[1],
                                             alternative_pref=standard_operation[2],
                                             standard_op_no=standard_operation[3],
                                             operation_type=standard_operation[4],
                                             standard_time=standard_operation[5],
                                             yield_percent=standard_operation[6])
                          for standard_operation in standard_operations]

for standard_operation in standard_operations_db:
    db.session.add(standard_operation)

db.session.commit()
# Out:
# 2023-06-08 21:06:33,024 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:33,027 INFO sqlalchemy.engine.Engine INSERT INTO standard_operation (product_id, resource_id, alternative_pref, standard_op_no, operation_type, standard_time, yield_percent) SELECT p0::INTEGER, p1::INTEGER, p2::INTEGER, p3::INTEGER, p4::VARCHAR, p5::NUMERIC(18, 3), p6::NUMERIC(18, 3) FR ... 2168 characters truncated ... ounter RETURNING standard_operation.operation_id, standard_operation.operation_id AS operation_id__1
# 2023-06-08 21:06:33,027 INFO sqlalchemy.engine.Engine [generated in 0.00008s (insertmanyvalues) 1/1 (ordered)] {'standard_op_no__0': 20, 'yield_percent__0': 0.984, 'resource_id__0': 1, 'standard_time__0': 155, 'operation_type__0': 1, 'product_id__0': 1, 'alternative_pref__0': 1, 'standard_op_no__1': 30, 'yield_percent__1': 1, 'resource_id__1': 5, 'standard_time__1': 150, 'operation_type__1': 1, 'product_id__1': 2, 'alternative_pref__1': 1, 'standard_op_no__2': 50, 'yield_percent__2': 0.984, 'resource_id__2': 6, 'standard_time__2': 150, 'operation_type__2': 1, 'product_id__2': 3, 'alternative_pref__2': 1, 'standard_op_no__3': 30, 'yield_percent__3': 1, 'resource_id__3': 5, 'standard_time__3': 150, 'operation_type__3': 1, 'product_id__3': 4, 'alternative_pref__3': 1, 'standard_op_no__4': 50, 'yield_percent__4': 0.984, 'resource_id__4': 6, 'standard_time__4': 150, 'operation_type__4': 1, 'product_id__4': 5, 'alternative_pref__4': 1, 'standard_op_no__5': 20, 'yield_percent__5': 0.984, 'resource_id__5': 1, 'standard_time__5': 155, 'operation_type__5': 1, 'product_id__5': 6, 'alternative_pref__5': 1, 'standard_op_no__6': 80, 'yield_percent__6': 0.984, 'resource_id__6': 3, 'standard_time__6': 200, 'operation_type__6': 1, 'product_id__6': 1, 'alternative_pref__6': 1, 'standard_op_no__7': 80, 'yield_percent__7': 0.984, 'resource_id__7': 3, 'standard_time__7': 200, 'operation_type__7': 1, 'product_id__7': 6, 'alternative_pref__7': 1, 'standard_op_no__8': 90, 'yield_percent__8': 1, 'resource_id__8': 2, 'standard_time__8': 180, 'operation_type__8': 1, 'product_id__8': 6, 'alternative_pref__8': 1, 'standard_op_no__9': 80, 'yield_percent__9': 0.984, 'resource_id__9': 4, 'standard_time__9': 150, 'operation_type__9': 1, 'product_id__9': 5, 'alternative_pref__9': 1, 'standard_op_no__10': 90, 'yield_percent__10': 1, 'resource_id__10': 7, 'standard_time__10': 200, 'operation_type__10': 1, 'product_id__10': 5, 'alternative_pref__10': 1, 'standard_op_no__11': 80, 'yield_percent__11': 0.984, 'resource_id__11': 4, 'standard_time__11': 150, 'operation_type__11': 1, 'product_id__11': 4, 'alternative_pref__11': 1, 'standard_op_no__12': 90, 'yield_percent__12': 1, 'resource_id__12': 7, 'standard_time__12': 200, 'operation_type__12': 1, 'product_id__12': 4, 'alternative_pref__12': 1}
# 2023-06-08 21:06:33,030 INFO sqlalchemy.engine.Engine COMMIT

# %%
product_link = [
    (1, "Г/К Лист", "сляб", "L", 20),
    (2, "Г/К Рулон травл", "Г/К Рулон", "L", 30),
    (3, "Г/К Рулон", "сляб", "L", 20),
    (4, "Г/К Рулон травл дрес", "Г/К Рулон травл", "L", 50),
    (5, "Г/К Лист травл дрес", "Г/К Лист травл", "L", 50),
    (6, "Г/К Лист травл", "Г/К Лист", "L", 30),
]

product_link_db = [Product_Link(product_link_id=product_link[0],
                                owner_pruduct=product_link[1],
                                component_product=product_link[2],
                                product_link_ty_id=product_link[3],
                                operation_id=product_link[4])
                     for product_link in product_link]

for product_link in product_link_db:
    db.session.add(product_link)

db.session.commit()
# Out:
# 2023-06-08 21:06:33,919 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:33,921 INFO sqlalchemy.engine.Engine INSERT INTO product_link (product_link_id, owner_pruduct, component_product, product_link_ty_id, operation_id) VALUES (%(product_link_id__0)s, %(owner_pruduct__0)s, %(component_product__0)s, %(product_link_ty_id__0)s, %(operation_id__0)s), (%(product ... 498 characters truncated ... 5)s, %(owner_pruduct__5)s, %(component_product__5)s, %(product_link_ty_id__5)s, %(operation_id__5)s)
# 2023-06-08 21:06:33,922 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/1 (unordered)] {'operation_id__0': 20, 'product_link_ty_id__0': 'L', 'product_link_id__0': 1, 'component_product__0': 'сляб', 'owner_pruduct__0': 'Г/К Лист', 'operation_id__1': 30, 'product_link_ty_id__1': 'L', 'product_link_id__1': 2, 'component_product__1': 'Г/К Рулон', 'owner_pruduct__1': 'Г/К Рулон травл', 'operation_id__2': 20, 'product_link_ty_id__2': 'L', 'product_link_id__2': 3, 'component_product__2': 'сляб', 'owner_pruduct__2': 'Г/К Рулон', 'operation_id__3': 50, 'product_link_ty_id__3': 'L', 'product_link_id__3': 4, 'component_product__3': 'Г/К Рулон травл', 'owner_pruduct__3': 'Г/К Рулон травл дрес', 'operation_id__4': 50, 'product_link_ty_id__4': 'L', 'product_link_id__4': 5, 'component_product__4': 'Г/К Лист травл', 'owner_pruduct__4': 'Г/К Лист травл дрес', 'operation_id__5': 30, 'product_link_ty_id__5': 'L', 'product_link_id__5': 6, 'component_product__5': 'Г/К Лист', 'owner_pruduct__5': 'Г/К Лист травл'}
# 2023-06-08 21:06:33,923 INFO sqlalchemy.engine.Engine COMMIT

# %%
sales_orders = [
    ('SO1001', 1, 1, 1950, 15, 12, 0, '2022-04-11', '2022-04-11'),
    ('SO1002', 2, 4, 2000, 10, 8, 0, '2022-04-18', '2022-04-18'),
    ('SO1003', 3, 3, 1750, 30, 25, 0, '2022-04-22', '2022-04-22'),
    ('SO1004', 4, 4, 7200, 15, 15, 0, '2022-04-30', '2022-04-30'),
    ('SO1005', 5, 2, 1950, 5, 5, 0, '2022-04-28', '2022-04-28'),
    ('SO1006', 6, 3, 3120, 35, 30, 0, '2022-04-10', '2022-04-10'),
    ('SO1007', 7, 1, 3800, 15, 10, 0, '2022-04-04', '2022-04-04'),
    ('SO1008', 8, 6, 2180, 20, 18, 0, '2022-04-12', '2022-04-12'),
]

sales_orders_db = [Sales_Orders(sales_order_id=sales_order[0],
                                customer_id=sales_order[1],
                                product_id=sales_order[2],
                                so_quantity=sales_order[3],
                                so_tolerance=sales_order[4],
                                shipped_quantity=sales_order[5],
                                so_status=sales_order[6],
                                orig_due_date=sales_order[7],
                                so_due_date=sales_order[8])
                        for sales_order in sales_orders]

for sales_order in sales_orders_db:
    db.session.add(sales_order)

db.session.commit()
# Out:
# 2023-06-08 21:06:34,967 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:34,968 INFO sqlalchemy.engine.Engine INSERT INTO sales_orders (sales_order_id, customer_id, product_id, so_quantity, so_tolerance, shipped_quantity, so_status, orig_due_date, so_due_date, release_date, ship_to_location, original_from_date) VALUES (%(sales_order_id__0)s, %(customer_id__0 ... 1962 characters truncated ... e__7)s, %(so_due_date__7)s, %(release_date__7)s, %(ship_to_location__7)s, %(original_from_date__7)s)
# 2023-06-08 21:06:34,968 INFO sqlalchemy.engine.Engine [generated in 0.00008s (insertmanyvalues) 1/1 (unordered)] {'ship_to_location__0': None, 'orig_due_date__0': '2022-04-11', 'so_tolerance__0': 15, 'so_status__0': 0, 'original_from_date__0': None, 'shipped_quantity__0': 12, 'release_date__0': None, 'sales_order_id__0': 'SO1001', 'so_due_date__0': '2022-04-11', 'so_quantity__0': 1950, 'customer_id__0': 1, 'product_id__0': 1, 'ship_to_location__1': None, 'orig_due_date__1': '2022-04-18', 'so_tolerance__1': 10, 'so_status__1': 0, 'original_from_date__1': None, 'shipped_quantity__1': 8, 'release_date__1': None, 'sales_order_id__1': 'SO1002', 'so_due_date__1': '2022-04-18', 'so_quantity__1': 2000, 'customer_id__1': 2, 'product_id__1': 4, 'ship_to_location__2': None, 'orig_due_date__2': '2022-04-22', 'so_tolerance__2': 30, 'so_status__2': 0, 'original_from_date__2': None, 'shipped_quantity__2': 25, 'release_date__2': None, 'sales_order_id__2': 'SO1003', 'so_due_date__2': '2022-04-22', 'so_quantity__2': 1750, 'customer_id__2': 3, 'product_id__2': 3, 'ship_to_location__3': None, 'orig_due_date__3': '2022-04-30', 'so_tolerance__3': 15, 'so_status__3': 0, 'original_from_date__3': None, 'shipped_quantity__3': 15, 'release_date__3': None, 'sales_order_id__3': 'SO1004', 'so_due_date__3': '2022-04-30', 'so_quantity__3': 7200, 'customer_id__3': 4, 'product_id__3': 4, 'ship_to_location__4': None, 'orig_due_date__4': '2022-04-28', 'so_tolerance__4': 5, 'so_status__4': 0, 'original_from_date__4': None, 'shipped_quantity__4': 5, 'release_date__4': None, 'sales_order_id__4': 'SO1005', 'so_due_date__4': '2022-04-28', 'so_quantity__4': 1950, 'customer_id__4': 5, 'product_id__4': 2, 'ship_to_location__5': None, 'orig_due_date__5': '2022-04-10', 'so_tolerance__5': 35, 'so_status__5': 0, 'original_from_date__5': None, 'shipped_quantity__5': 30, 'release_date__5': None, 'sales_order_id__5': 'SO1006', 'so_due_date__5': '2022-04-10', 'so_quantity__5': 3120, 'customer_id__5': 6, 'product_id__5': 3, 'ship_to_location__6': None, 'orig_due_date__6': '2022-04-04', 'so_tolerance__6': 15, 'so_status__6': 0, 'original_from_date__6': None, 'shipped_quantity__6': 10, 'release_date__6': None, 'sales_order_id__6': 'SO1007', 'so_due_date__6': '2022-04-04', 'so_quantity__6': 3800, 'customer_id__6': 7, 'product_id__6': 1, 'ship_to_location__7': None, 'orig_due_date__7': '2022-04-12', 'so_tolerance__7': 20, 'so_status__7': 0, 'original_from_date__7': None, 'shipped_quantity__7': 18, 'release_date__7': None, 'sales_order_id__7': 'SO1008', 'so_due_date__7': '2022-04-12', 'so_quantity__7': 2180, 'customer_id__7': 8, 'product_id__7': 6}
# 2023-06-08 21:06:34,970 INFO sqlalchemy.engine.Engine COMMIT

# %%
import datetime

# %%
def balancing(target: int, unit_weight: int, resources) -> int:
    time = (target / resources[0].standard_time) * 60

    if time / 60 > 23:
        time += 60

    return float(time)

# %%
from decimal import Decimal

# %%
def recursive_mrp(product_id: int,
                  unit_weight: float,
                  target: int,
                  release_date: str,
                  quantity: int,
                  sales_order_id: Optional[str],
                  operation_id: int = None) -> None:

    last_record = db.session.query(MRP_Plan)\
        .filter(MRP_Plan.sales_order_id == sales_order_id)\
        .order_by(desc(MRP_Plan.release_date))\
        .first()

    if operation_id is None:
        # Считаем время на упаковку
        if product_id in [1, 6]:
            p, s = 1, 1
        else:
            p, s = 2, 2

        resources = db.session.query(Resource, Standard_Operation.standard_time)\
        .join(Standard_Operation)\
        .filter(Resource.resource_desc == f'Линия упаковки{p}')\
        .all()

        time = balancing(target, unit_weight, resources)

        db.session.add(MRP_Plan(product_id=product_id,
                                quantity=quantity,
                                weight=target,
                                release_date=release_date,
                                sales_order_id=sales_order_id))
        db.session.commit()

        release_date = release_date - datetime.timedelta(minutes=time)


        #Считаем резку
        resources = db.session.query(Resource, Standard_Operation.standard_time)\
        .join(Standard_Operation)\
        .filter(Resource.resource_desc == f'Агрегат резки{s}')\
        .all()

        time = balancing(target, unit_weight, resources)

        unit_weight = unit_weight / Decimal(0.984)
        target = unit_weight * quantity

        db.session.add(MRP_Plan(product_id=product_id,
                                quantity=target / unit_weight,
                                weight=target,
                                release_date=release_date,
                                sales_order_id=sales_order_id))
        db.session.commit()

        release_date = release_date - datetime.timedelta(minutes=time)

    else:
        resources = db.session.query(Standard_Operation)\
            .filter(Standard_Operation.standard_op_no == operation_id)\
            .all()

        unit_weight = unit_weight / resources[0].yield_percent
        target = unit_weight * quantity

        time = balancing(target, unit_weight, resources)

        db.session.add(MRP_Plan(product_id=product_id,
                                quantity=quantity,
                                weight=target,
                                release_date=release_date,
                                sales_order_id=sales_order_id))
        db.session.commit()

        release_date = release_date - datetime.timedelta(minutes=time)


    product_name = db.session.query(Product.product_desc)\
        .filter(Product.product_id == product_id)\
        .one()[0]

    try:
        component = db.session.query(Product_Link)\
            .filter(Product_Link.owner_pruduct == product_name)\
            .one()
    except NoResultFound:
        return None

    product_id = db.session.query(Product.product_id)\
        .filter(Product.product_desc == component.component_product.strip())\
        .one()[0]

    return recursive_mrp(product_id, unit_weight, target, release_date, quantity, sales_order_id, component.operation_id)

# %%
from math import floor

# %%
orders = [a for a in db.session.query(Sales_Orders).join(Customer).order_by(Customer.customer_priority).all()]

for order in orders:
    quantity = floor(order.so_quantity / order.shipped_quantity)
    recursive_mrp(order.product_id, order.shipped_quantity, order.so_quantity, order.so_due_date, quantity, order.sales_order_id)
# Out:
# 2023-06-08 21:06:40,645 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,647 INFO sqlalchemy.engine.Engine SELECT sales_orders.sales_order_id AS sales_orders_sales_order_id, sales_orders.customer_id AS sales_orders_customer_id, sales_orders.product_id AS sales_orders_product_id, sales_orders.so_quantity AS sales_orders_so_quantity, sales_orders.so_tolerance AS sales_orders_so_tolerance, sales_orders.shipped_quantity AS sales_orders_shipped_quantity, sales_orders.so_status AS sales_orders_so_status, sales_orders.orig_due_date AS sales_orders_orig_due_date, sales_orders.so_due_date AS sales_orders_so_due_date, sales_orders.release_date AS sales_orders_release_date, sales_orders.ship_to_location AS sales_orders_ship_to_location, sales_orders.original_from_date AS sales_orders_original_from_date
# FROM sales_orders JOIN customer ON customer.customer_id = sales_orders.customer_id ORDER BY customer.customer_priority
# 2023-06-08 21:06:40,648 INFO sqlalchemy.engine.Engine [generated in 0.00081s] {}
# 2023-06-08 21:06:40,651 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,651 INFO sqlalchemy.engine.Engine [generated in 0.00048s] {'sales_order_id_1': 'SO1004', 'param_1': 1}
# 2023-06-08 21:06:40,653 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:06:40,653 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {'resource_desc_1': 'Линия упаковки2'}
# 2023-06-08 21:06:40,655 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,655 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {'product_id': 4, 'quantity': 480, 'weight': Decimal('7200.000'), 'release_date': datetime.datetime(2022, 4, 30, 0, 0), 'sales_order_id': 'SO1004'}
# 2023-06-08 21:06:40,656 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,657 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,658 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:06:40,658 INFO sqlalchemy.engine.Engine [cached since 0.004749s ago] {'resource_desc_1': 'Агрегат резки2'}
# 2023-06-08 21:06:40,660 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,660 INFO sqlalchemy.engine.Engine [cached since 0.005473s ago] {'product_id': 4, 'quantity': Decimal('480.0000000000000000000000000'), 'weight': Decimal('7317.073170731707422745796515'), 'release_date': datetime.datetime(2022, 4, 28, 11, 0), 'sales_order_id': 'SO1004'}
# 2023-06-08 21:06:40,662 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,663 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,663 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,664 INFO sqlalchemy.engine.Engine [generated in 0.00028s] {'product_id_1': 4}
# 2023-06-08 21:06:40,665 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,666 INFO sqlalchemy.engine.Engine [generated in 0.00050s] {'owner_pruduct_1': 'Г/К Лист травл'}
# 2023-06-08 21:06:40,666 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:06:40,667 INFO sqlalchemy.engine.Engine [generated in 0.00024s] {'product_desc_1': 'Г/К Лист'}
# 2023-06-08 21:06:40,667 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,667 INFO sqlalchemy.engine.Engine [cached since 0.01667s ago] {'sales_order_id_1': 'SO1004', 'param_1': 1}
# 2023-06-08 21:06:40,668 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:06:40,669 INFO sqlalchemy.engine.Engine [generated in 0.00032s] {'standard_op_no_1': 30}
# 2023-06-08 21:06:40,670 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,670 INFO sqlalchemy.engine.Engine [cached since 0.01534s ago] {'product_id': 1, 'quantity': 480, 'weight': Decimal('7317.073170731707422745796515'), 'release_date': datetime.datetime(2022, 4, 26, 10, 0), 'sales_order_id': 'SO1004'}
# 2023-06-08 21:06:40,671 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,672 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,672 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,672 INFO sqlalchemy.engine.Engine [cached since 0.008925s ago] {'product_id_1': 1}
# 2023-06-08 21:06:40,673 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,673 INFO sqlalchemy.engine.Engine [cached since 0.008064s ago] {'owner_pruduct_1': 'Г/К Лист'}
# 2023-06-08 21:06:40,674 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:06:40,674 INFO sqlalchemy.engine.Engine [cached since 0.00778s ago] {'product_desc_1': 'сляб'}
# 2023-06-08 21:06:40,676 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,676 INFO sqlalchemy.engine.Engine [cached since 0.02503s ago] {'sales_order_id_1': 'SO1004', 'param_1': 1}
# 2023-06-08 21:06:40,677 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:06:40,677 INFO sqlalchemy.engine.Engine [cached since 0.008437s ago] {'standard_op_no_1': 20}
# 2023-06-08 21:06:40,678 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,679 INFO sqlalchemy.engine.Engine [cached since 0.0239s ago] {'product_id': 7, 'quantity': 480, 'weight': Decimal('7436.049970255800226367679384'), 'release_date': datetime.datetime(2022, 4, 24, 8, 13, 10, 243902), 'sales_order_id': 'SO1004'}
# 2023-06-08 21:06:40,679 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,680 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,681 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,681 INFO sqlalchemy.engine.Engine [cached since 0.01746s ago] {'product_id_1': 7}
# 2023-06-08 21:06:40,682 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,682 INFO sqlalchemy.engine.Engine [cached since 0.01668s ago] {'owner_pruduct_1': 'сляб'}
# 2023-06-08 21:06:40,683 INFO sqlalchemy.engine.Engine SELECT sales_orders.sales_order_id AS sales_orders_sales_order_id, sales_orders.customer_id AS sales_orders_customer_id, sales_orders.product_id AS sales_orders_product_id, sales_orders.so_quantity AS sales_orders_so_quantity, sales_orders.so_tolerance AS sales_orders_so_tolerance, sales_orders.shipped_quantity AS sales_orders_shipped_quantity, sales_orders.so_status AS sales_orders_so_status, sales_orders.orig_due_date AS sales_orders_orig_due_date, sales_orders.so_due_date AS sales_orders_so_due_date, sales_orders.release_date AS sales_orders_release_date, sales_orders.ship_to_location AS sales_orders_ship_to_location, sales_orders.original_from_date AS sales_orders_original_from_date
# FROM sales_orders
# WHERE sales_orders.sales_order_id = %(pk_1)s
# 2023-06-08 21:06:40,683 INFO sqlalchemy.engine.Engine [generated in 0.00020s] {'pk_1': 'SO1008'}
# 2023-06-08 21:06:40,684 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,684 INFO sqlalchemy.engine.Engine [cached since 0.03302s ago] {'sales_order_id_1': 'SO1008', 'param_1': 1}
# 2023-06-08 21:06:40,684 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:06:40,685 INFO sqlalchemy.engine.Engine [cached since 0.03144s ago] {'resource_desc_1': 'Линия упаковки1'}
# 2023-06-08 21:06:40,685 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,685 INFO sqlalchemy.engine.Engine [cached since 0.03064s ago] {'product_id': 6, 'quantity': 121, 'weight': Decimal('2180.000'), 'release_date': datetime.datetime(2022, 4, 12, 0, 0), 'sales_order_id': 'SO1008'}
# 2023-06-08 21:06:40,686 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,687 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,687 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:06:40,687 INFO sqlalchemy.engine.Engine [cached since 0.0338s ago] {'resource_desc_1': 'Агрегат резки1'}
# 2023-06-08 21:06:40,688 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,688 INFO sqlalchemy.engine.Engine [cached since 0.03301s ago] {'product_id': 6, 'quantity': Decimal('121.0000000000000000000000000'), 'weight': Decimal('2213.414634146341495380603445'), 'release_date': datetime.datetime(2022, 4, 11, 11, 53, 20), 'sales_order_id': 'SO1008'}
# 2023-06-08 21:06:40,688 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,689 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,689 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,689 INFO sqlalchemy.engine.Engine [cached since 0.0257s ago] {'product_id_1': 6}
# 2023-06-08 21:06:40,690 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,690 INFO sqlalchemy.engine.Engine [cached since 0.02489s ago] {'owner_pruduct_1': 'Г/К Рулон'}
# 2023-06-08 21:06:40,691 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:06:40,692 INFO sqlalchemy.engine.Engine [cached since 0.02523s ago] {'product_desc_1': 'сляб'}
# 2023-06-08 21:06:40,692 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,693 INFO sqlalchemy.engine.Engine [cached since 0.04187s ago] {'sales_order_id_1': 'SO1008', 'param_1': 1}
# 2023-06-08 21:06:40,693 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:06:40,694 INFO sqlalchemy.engine.Engine [cached since 0.02529s ago] {'standard_op_no_1': 20}
# 2023-06-08 21:06:40,695 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,695 INFO sqlalchemy.engine.Engine [cached since 0.04022s ago] {'product_id': 7, 'quantity': 121, 'weight': Decimal('2249.405116002379568476223014'), 'release_date': datetime.datetime(2022, 4, 11, 0, 59, 20), 'sales_order_id': 'SO1008'}
# 2023-06-08 21:06:40,696 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,697 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,697 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,697 INFO sqlalchemy.engine.Engine [cached since 0.03356s ago] {'product_id_1': 7}
# 2023-06-08 21:06:40,698 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,698 INFO sqlalchemy.engine.Engine [cached since 0.03281s ago] {'owner_pruduct_1': 'сляб'}
# 2023-06-08 21:06:40,698 INFO sqlalchemy.engine.Engine SELECT sales_orders.sales_order_id AS sales_orders_sales_order_id, sales_orders.customer_id AS sales_orders_customer_id, sales_orders.product_id AS sales_orders_product_id, sales_orders.so_quantity AS sales_orders_so_quantity, sales_orders.so_tolerance AS sales_orders_so_tolerance, sales_orders.shipped_quantity AS sales_orders_shipped_quantity, sales_orders.so_status AS sales_orders_so_status, sales_orders.orig_due_date AS sales_orders_orig_due_date, sales_orders.so_due_date AS sales_orders_so_due_date, sales_orders.release_date AS sales_orders_release_date, sales_orders.ship_to_location AS sales_orders_ship_to_location, sales_orders.original_from_date AS sales_orders_original_from_date
# FROM sales_orders
# WHERE sales_orders.sales_order_id = %(pk_1)s
# 2023-06-08 21:06:40,699 INFO sqlalchemy.engine.Engine [cached since 0.01575s ago] {'pk_1': 'SO1002'}
# 2023-06-08 21:06:40,699 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,699 INFO sqlalchemy.engine.Engine [cached since 0.04853s ago] {'sales_order_id_1': 'SO1002', 'param_1': 1}
# 2023-06-08 21:06:40,700 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:06:40,700 INFO sqlalchemy.engine.Engine [cached since 0.04692s ago] {'resource_desc_1': 'Линия упаковки2'}
# 2023-06-08 21:06:40,701 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,702 INFO sqlalchemy.engine.Engine [cached since 0.04696s ago] {'product_id': 4, 'quantity': 250, 'weight': Decimal('2000.000'), 'release_date': datetime.datetime(2022, 4, 18, 0, 0), 'sales_order_id': 'SO1002'}
# 2023-06-08 21:06:40,703 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,704 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,704 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:06:40,704 INFO sqlalchemy.engine.Engine [cached since 0.05109s ago] {'resource_desc_1': 'Агрегат резки2'}
# 2023-06-08 21:06:40,705 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,705 INFO sqlalchemy.engine.Engine [cached since 0.0505s ago] {'product_id': 4, 'quantity': Decimal('2.5E+2'), 'weight': Decimal('2032.520325203252061873832365'), 'release_date': datetime.datetime(2022, 4, 17, 14, 0), 'sales_order_id': 'SO1002'}
# 2023-06-08 21:06:40,706 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,706 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,707 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,707 INFO sqlalchemy.engine.Engine [cached since 0.04347s ago] {'product_id_1': 4}
# 2023-06-08 21:06:40,708 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,708 INFO sqlalchemy.engine.Engine [cached since 0.04279s ago] {'owner_pruduct_1': 'Г/К Лист травл'}
# 2023-06-08 21:06:40,708 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:06:40,708 INFO sqlalchemy.engine.Engine [cached since 0.04206s ago] {'product_desc_1': 'Г/К Лист'}
# 2023-06-08 21:06:40,709 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,709 INFO sqlalchemy.engine.Engine [cached since 0.05845s ago] {'sales_order_id_1': 'SO1002', 'param_1': 1}
# 2023-06-08 21:06:40,710 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:06:40,710 INFO sqlalchemy.engine.Engine [cached since 0.04176s ago] {'standard_op_no_1': 30}
# 2023-06-08 21:06:40,711 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,712 INFO sqlalchemy.engine.Engine [cached since 0.05747s ago] {'product_id': 1, 'quantity': 250, 'weight': Decimal('2032.520325203252061873832365'), 'release_date': datetime.datetime(2022, 4, 17, 0, 40), 'sales_order_id': 'SO1002'}
# 2023-06-08 21:06:40,713 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,714 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,714 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,714 INFO sqlalchemy.engine.Engine [cached since 0.05081s ago] {'product_id_1': 1}
# 2023-06-08 21:06:40,715 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,715 INFO sqlalchemy.engine.Engine [cached since 0.04997s ago] {'owner_pruduct_1': 'Г/К Лист'}
# 2023-06-08 21:06:40,715 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:06:40,716 INFO sqlalchemy.engine.Engine [cached since 0.04916s ago] {'product_desc_1': 'сляб'}
# 2023-06-08 21:06:40,716 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,716 INFO sqlalchemy.engine.Engine [cached since 0.06544s ago] {'sales_order_id_1': 'SO1002', 'param_1': 1}
# 2023-06-08 21:06:40,717 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:06:40,717 INFO sqlalchemy.engine.Engine [cached since 0.04846s ago] {'standard_op_no_1': 20}
# 2023-06-08 21:06:40,717 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,718 INFO sqlalchemy.engine.Engine [cached since 0.06281s ago] {'product_id': 7, 'quantity': 250, 'weight': Decimal('2065.569436182166729546577607'), 'release_date': datetime.datetime(2022, 4, 16, 11, 6, 59, 512195), 'sales_order_id': 'SO1002'}
# 2023-06-08 21:06:40,718 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,719 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,719 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,719 INFO sqlalchemy.engine.Engine [cached since 0.05561s ago] {'product_id_1': 7}
# 2023-06-08 21:06:40,720 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,720 INFO sqlalchemy.engine.Engine [cached since 0.05465s ago] {'owner_pruduct_1': 'сляб'}
# 2023-06-08 21:06:40,720 INFO sqlalchemy.engine.Engine SELECT sales_orders.sales_order_id AS sales_orders_sales_order_id, sales_orders.customer_id AS sales_orders_customer_id, sales_orders.product_id AS sales_orders_product_id, sales_orders.so_quantity AS sales_orders_so_quantity, sales_orders.so_tolerance AS sales_orders_so_tolerance, sales_orders.shipped_quantity AS sales_orders_shipped_quantity, sales_orders.so_status AS sales_orders_so_status, sales_orders.orig_due_date AS sales_orders_orig_due_date, sales_orders.so_due_date AS sales_orders_so_due_date, sales_orders.release_date AS sales_orders_release_date, sales_orders.ship_to_location AS sales_orders_ship_to_location, sales_orders.original_from_date AS sales_orders_original_from_date
# FROM sales_orders
# WHERE sales_orders.sales_order_id = %(pk_1)s
# 2023-06-08 21:06:40,721 INFO sqlalchemy.engine.Engine [cached since 0.03774s ago] {'pk_1': 'SO1001'}
# 2023-06-08 21:06:40,721 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,721 INFO sqlalchemy.engine.Engine [cached since 0.07057s ago] {'sales_order_id_1': 'SO1001', 'param_1': 1}
# 2023-06-08 21:06:40,722 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:06:40,722 INFO sqlalchemy.engine.Engine [cached since 0.06903s ago] {'resource_desc_1': 'Линия упаковки1'}
# 2023-06-08 21:06:40,723 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,723 INFO sqlalchemy.engine.Engine [cached since 0.06824s ago] {'product_id': 1, 'quantity': 162, 'weight': Decimal('1950.000'), 'release_date': datetime.datetime(2022, 4, 11, 0, 0), 'sales_order_id': 'SO1001'}
# 2023-06-08 21:06:40,724 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,724 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,725 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:06:40,725 INFO sqlalchemy.engine.Engine [cached since 0.07174s ago] {'resource_desc_1': 'Агрегат резки1'}
# 2023-06-08 21:06:40,727 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,727 INFO sqlalchemy.engine.Engine [cached since 0.0725s ago] {'product_id': 1, 'quantity': Decimal('162.0000000000000000000000000'), 'weight': Decimal('1975.609756097561004141365059'), 'release_date': datetime.datetime(2022, 4, 10, 13, 10), 'sales_order_id': 'SO1001'}
# 2023-06-08 21:06:40,729 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,730 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,730 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,730 INFO sqlalchemy.engine.Engine [cached since 0.06711s ago] {'product_id_1': 1}
# 2023-06-08 21:06:40,731 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,732 INFO sqlalchemy.engine.Engine [cached since 0.06667s ago] {'owner_pruduct_1': 'Г/К Лист'}
# 2023-06-08 21:06:40,732 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:06:40,733 INFO sqlalchemy.engine.Engine [cached since 0.06617s ago] {'product_desc_1': 'сляб'}
# 2023-06-08 21:06:40,733 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,733 INFO sqlalchemy.engine.Engine [cached since 0.08251s ago] {'sales_order_id_1': 'SO1001', 'param_1': 1}
# 2023-06-08 21:06:40,734 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:06:40,734 INFO sqlalchemy.engine.Engine [cached since 0.06554s ago] {'standard_op_no_1': 20}
# 2023-06-08 21:06:40,735 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,735 INFO sqlalchemy.engine.Engine [cached since 0.07995s ago] {'product_id': 7, 'quantity': 162, 'weight': Decimal('2007.733491969066061119273434'), 'release_date': datetime.datetime(2022, 4, 10, 3, 25), 'sales_order_id': 'SO1001'}
# 2023-06-08 21:06:40,735 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,736 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,736 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,736 INFO sqlalchemy.engine.Engine [cached since 0.07306s ago] {'product_id_1': 7}
# 2023-06-08 21:06:40,737 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,737 INFO sqlalchemy.engine.Engine [cached since 0.07244s ago] {'owner_pruduct_1': 'сляб'}
# 2023-06-08 21:06:40,738 INFO sqlalchemy.engine.Engine SELECT sales_orders.sales_order_id AS sales_orders_sales_order_id, sales_orders.customer_id AS sales_orders_customer_id, sales_orders.product_id AS sales_orders_product_id, sales_orders.so_quantity AS sales_orders_so_quantity, sales_orders.so_tolerance AS sales_orders_so_tolerance, sales_orders.shipped_quantity AS sales_orders_shipped_quantity, sales_orders.so_status AS sales_orders_so_status, sales_orders.orig_due_date AS sales_orders_orig_due_date, sales_orders.so_due_date AS sales_orders_so_due_date, sales_orders.release_date AS sales_orders_release_date, sales_orders.ship_to_location AS sales_orders_ship_to_location, sales_orders.original_from_date AS sales_orders_original_from_date
# FROM sales_orders
# WHERE sales_orders.sales_order_id = %(pk_1)s
# 2023-06-08 21:06:40,738 INFO sqlalchemy.engine.Engine [cached since 0.05539s ago] {'pk_1': 'SO1003'}
# 2023-06-08 21:06:40,739 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,739 INFO sqlalchemy.engine.Engine [cached since 0.08818s ago] {'sales_order_id_1': 'SO1003', 'param_1': 1}
# 2023-06-08 21:06:40,740 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:06:40,740 INFO sqlalchemy.engine.Engine [cached since 0.08668s ago] {'resource_desc_1': 'Линия упаковки2'}
# 2023-06-08 21:06:40,741 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,741 INFO sqlalchemy.engine.Engine [cached since 0.08606s ago] {'product_id': 3, 'quantity': 70, 'weight': Decimal('1750.000'), 'release_date': datetime.datetime(2022, 4, 22, 0, 0), 'sales_order_id': 'SO1003'}
# 2023-06-08 21:06:40,741 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,742 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,742 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:06:40,742 INFO sqlalchemy.engine.Engine [cached since 0.08929s ago] {'resource_desc_1': 'Агрегат резки2'}
# 2023-06-08 21:06:40,743 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,743 INFO sqlalchemy.engine.Engine [cached since 0.08847s ago] {'product_id': 3, 'quantity': Decimal('69.99999999999999999999999999'), 'weight': Decimal('1778.455284552845554139603319'), 'release_date': datetime.datetime(2022, 4, 21, 15, 15), 'sales_order_id': 'SO1003'}
# 2023-06-08 21:06:40,744 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,744 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,744 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,744 INFO sqlalchemy.engine.Engine [cached since 0.08112s ago] {'product_id_1': 3}
# 2023-06-08 21:06:40,745 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,745 INFO sqlalchemy.engine.Engine [cached since 0.08022s ago] {'owner_pruduct_1': 'Г/К Рулон травл дрес'}
# 2023-06-08 21:06:40,746 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:06:40,746 INFO sqlalchemy.engine.Engine [cached since 0.07954s ago] {'product_desc_1': 'Г/К Рулон травл'}
# 2023-06-08 21:06:40,746 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,747 INFO sqlalchemy.engine.Engine [cached since 0.09579s ago] {'sales_order_id_1': 'SO1003', 'param_1': 1}
# 2023-06-08 21:06:40,747 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:06:40,748 INFO sqlalchemy.engine.Engine [cached since 0.0791s ago] {'standard_op_no_1': 50}
# 2023-06-08 21:06:40,748 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,748 INFO sqlalchemy.engine.Engine [cached since 0.09364s ago] {'product_id': 2, 'quantity': 70, 'weight': Decimal('1807.373256659395888353255406'), 'release_date': datetime.datetime(2022, 4, 21, 3, 35), 'sales_order_id': 'SO1003'}
# 2023-06-08 21:06:40,749 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,749 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,750 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,750 INFO sqlalchemy.engine.Engine [cached since 0.08645s ago] {'product_id_1': 2}
# 2023-06-08 21:06:40,750 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,751 INFO sqlalchemy.engine.Engine [cached since 0.08554s ago] {'owner_pruduct_1': 'Г/К Рулон травл'}
# 2023-06-08 21:06:40,751 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:06:40,751 INFO sqlalchemy.engine.Engine [cached since 0.08498s ago] {'product_desc_1': 'Г/К Рулон'}
# 2023-06-08 21:06:40,752 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,752 INFO sqlalchemy.engine.Engine [cached since 0.1013s ago] {'sales_order_id_1': 'SO1003', 'param_1': 1}
# ...
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:06:40,846 INFO sqlalchemy.engine.Engine [cached since 0.178s ago] {'standard_op_no_1': 20}
# 2023-06-08 21:06:40,847 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,847 INFO sqlalchemy.engine.Engine [cached since 0.1923s ago] {'product_id': 7, 'quantity': 390, 'weight': Decimal('2013.930200277612561307913166'), 'release_date': datetime.datetime(2022, 4, 26, 12, 2, 19, 24390), 'sales_order_id': 'SO1005'}
# 2023-06-08 21:06:40,848 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,848 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,848 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,849 INFO sqlalchemy.engine.Engine [cached since 0.1852s ago] {'product_id_1': 7}
# 2023-06-08 21:06:40,849 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,849 INFO sqlalchemy.engine.Engine [cached since 0.1844s ago] {'owner_pruduct_1': 'сляб'}
# 2023-06-08 21:06:40,850 INFO sqlalchemy.engine.Engine SELECT sales_orders.sales_order_id AS sales_orders_sales_order_id, sales_orders.customer_id AS sales_orders_customer_id, sales_orders.product_id AS sales_orders_product_id, sales_orders.so_quantity AS sales_orders_so_quantity, sales_orders.so_tolerance AS sales_orders_so_tolerance, sales_orders.shipped_quantity AS sales_orders_shipped_quantity, sales_orders.so_status AS sales_orders_so_status, sales_orders.orig_due_date AS sales_orders_orig_due_date, sales_orders.so_due_date AS sales_orders_so_due_date, sales_orders.release_date AS sales_orders_release_date, sales_orders.ship_to_location AS sales_orders_ship_to_location, sales_orders.original_from_date AS sales_orders_original_from_date
# FROM sales_orders
# WHERE sales_orders.sales_order_id = %(pk_1)s
# 2023-06-08 21:06:40,850 INFO sqlalchemy.engine.Engine [cached since 0.1673s ago] {'pk_1': 'SO1006'}
# 2023-06-08 21:06:40,853 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,853 INFO sqlalchemy.engine.Engine [cached since 0.2021s ago] {'sales_order_id_1': 'SO1006', 'param_1': 1}
# 2023-06-08 21:06:40,854 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:06:40,854 INFO sqlalchemy.engine.Engine [cached since 0.201s ago] {'resource_desc_1': 'Линия упаковки2'}
# 2023-06-08 21:06:40,856 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,856 INFO sqlalchemy.engine.Engine [cached since 0.2016s ago] {'product_id': 3, 'quantity': 104, 'weight': Decimal('3120.000'), 'release_date': datetime.datetime(2022, 4, 10, 0, 0), 'sales_order_id': 'SO1006'}
# 2023-06-08 21:06:40,867 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,873 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,873 INFO sqlalchemy.engine.Engine SELECT resource.resource_id AS resource_resource_id, resource.resource_desc AS resource_resource_desc, resource.wearout_factor AS resource_wearout_factor, resource.start_maintenance AS resource_start_maintenance, resource.end_maintenance AS resource_end_maintenance, resource.status AS resource_status, standard_operation.standard_time AS standard_operation_standard_time
# FROM resource JOIN standard_operation ON resource.resource_id = standard_operation.resource_id
# WHERE resource.resource_desc = %(resource_desc_1)s
# 2023-06-08 21:06:40,874 INFO sqlalchemy.engine.Engine [cached since 0.2205s ago] {'resource_desc_1': 'Агрегат резки2'}
# 2023-06-08 21:06:40,875 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,875 INFO sqlalchemy.engine.Engine [cached since 0.2208s ago] {'product_id': 3, 'quantity': Decimal('104.0000000000000000000000000'), 'weight': Decimal('3170.731707317073216523178489'), 'release_date': datetime.datetime(2022, 4, 9, 8, 24), 'sales_order_id': 'SO1006'}
# 2023-06-08 21:06:40,876 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,881 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,882 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,883 INFO sqlalchemy.engine.Engine [cached since 0.2192s ago] {'product_id_1': 3}
# 2023-06-08 21:06:40,884 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,884 INFO sqlalchemy.engine.Engine [cached since 0.2188s ago] {'owner_pruduct_1': 'Г/К Рулон травл дрес'}
# 2023-06-08 21:06:40,886 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:06:40,886 INFO sqlalchemy.engine.Engine [cached since 0.2197s ago] {'product_desc_1': 'Г/К Рулон травл'}
# 2023-06-08 21:06:40,887 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,887 INFO sqlalchemy.engine.Engine [cached since 0.2365s ago] {'sales_order_id_1': 'SO1006', 'param_1': 1}
# 2023-06-08 21:06:40,888 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:06:40,888 INFO sqlalchemy.engine.Engine [cached since 0.2196s ago] {'standard_op_no_1': 50}
# 2023-06-08 21:06:40,889 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,889 INFO sqlalchemy.engine.Engine [cached since 0.234s ago] {'product_id': 2, 'quantity': 104, 'weight': Decimal('3222.288320444180098092661066'), 'release_date': datetime.datetime(2022, 4, 8, 11, 36), 'sales_order_id': 'SO1006'}
# 2023-06-08 21:06:40,889 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,890 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,890 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,890 INFO sqlalchemy.engine.Engine [cached since 0.227s ago] {'product_id_1': 2}
# 2023-06-08 21:06:40,891 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,891 INFO sqlalchemy.engine.Engine [cached since 0.2261s ago] {'owner_pruduct_1': 'Г/К Рулон травл'}
# 2023-06-08 21:06:40,892 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:06:40,892 INFO sqlalchemy.engine.Engine [cached since 0.2253s ago] {'product_desc_1': 'Г/К Рулон'}
# 2023-06-08 21:06:40,892 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,892 INFO sqlalchemy.engine.Engine [cached since 0.2416s ago] {'sales_order_id_1': 'SO1006', 'param_1': 1}
# 2023-06-08 21:06:40,893 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:06:40,893 INFO sqlalchemy.engine.Engine [cached since 0.2247s ago] {'standard_op_no_1': 30}
# 2023-06-08 21:06:40,894 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,894 INFO sqlalchemy.engine.Engine [cached since 0.2391s ago] {'product_id': 6, 'quantity': 104, 'weight': Decimal('3222.288320444180098092661066'), 'release_date': datetime.datetime(2022, 4, 7, 14, 7, 5, 80309), 'sales_order_id': 'SO1006'}
# 2023-06-08 21:06:40,894 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,895 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,895 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,896 INFO sqlalchemy.engine.Engine [cached since 0.2322s ago] {'product_id_1': 6}
# 2023-06-08 21:06:40,896 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,897 INFO sqlalchemy.engine.Engine [cached since 0.2316s ago] {'owner_pruduct_1': 'Г/К Рулон'}
# 2023-06-08 21:06:40,897 INFO sqlalchemy.engine.Engine SELECT product.product_id AS product_product_id
# FROM product
# WHERE product.product_desc = %(product_desc_1)s
# 2023-06-08 21:06:40,897 INFO sqlalchemy.engine.Engine [cached since 0.231s ago] {'product_desc_1': 'сляб'}
# 2023-06-08 21:06:40,898 INFO sqlalchemy.engine.Engine SELECT mrp_plan.id AS mrp_plan_id, mrp_plan.product_id AS mrp_plan_product_id, mrp_plan.quantity AS mrp_plan_quantity, mrp_plan.weight AS mrp_plan_weight, mrp_plan.release_date AS mrp_plan_release_date, mrp_plan.sales_order_id AS mrp_plan_sales_order_id
# FROM mrp_plan
# WHERE mrp_plan.sales_order_id = %(sales_order_id_1)s ORDER BY mrp_plan.release_date DESC
#  LIMIT %(param_1)s
# 2023-06-08 21:06:40,899 INFO sqlalchemy.engine.Engine [cached since 0.2478s ago] {'sales_order_id_1': 'SO1006', 'param_1': 1}
# 2023-06-08 21:06:40,899 INFO sqlalchemy.engine.Engine SELECT standard_operation.operation_id AS standard_operation_operation_id, standard_operation.product_id AS standard_operation_product_id, standard_operation.resource_id AS standard_operation_resource_id, standard_operation.alternative_pref AS standard_operation_alternative_pref, standard_operation.standard_op_no AS standard_operation_standard_op_no, standard_operation.operation_type AS standard_operation_operation_type, standard_operation.standard_time AS standard_operation_standard_time, standard_operation.yield_percent AS standard_operation_yield_percent
# FROM standard_operation
# WHERE standard_operation.standard_op_no = %(standard_op_no_1)s
# 2023-06-08 21:06:40,899 INFO sqlalchemy.engine.Engine [cached since 0.231s ago] {'standard_op_no_1': 20}
# 2023-06-08 21:06:40,900 INFO sqlalchemy.engine.Engine INSERT INTO mrp_plan (product_id, quantity, weight, release_date, sales_order_id) VALUES (%(product_id)s, %(quantity)s, %(weight)s, %(release_date)s, %(sales_order_id)s) RETURNING mrp_plan.id
# 2023-06-08 21:06:40,900 INFO sqlalchemy.engine.Engine [cached since 0.2455s ago] {'product_id': 7, 'quantity': 104, 'weight': Decimal('3274.683252483922863915305962'), 'release_date': datetime.datetime(2022, 4, 6, 16, 38, 10, 160618), 'sales_order_id': 'SO1006'}
# 2023-06-08 21:06:40,901 INFO sqlalchemy.engine.Engine COMMIT
# 2023-06-08 21:06:40,901 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-06-08 21:06:40,902 INFO sqlalchemy.engine.Engine SELECT product.product_desc AS product_product_desc
# FROM product
# WHERE product.product_id = %(product_id_1)s
# 2023-06-08 21:06:40,902 INFO sqlalchemy.engine.Engine [cached since 0.2389s ago] {'product_id_1': 7}
# 2023-06-08 21:06:40,903 INFO sqlalchemy.engine.Engine SELECT product_link.product_link_id AS product_link_product_link_id, product_link.owner_pruduct AS product_link_owner_pruduct, product_link.component_product AS product_link_component_product, product_link.product_link_ty_id AS product_link_product_link_ty_id, product_link.operation_id AS product_link_operation_id
# FROM product_link
# WHERE product_link.owner_pruduct = %(owner_pruduct_1)s
# 2023-06-08 21:06:40,903 INFO sqlalchemy.engine.Engine [cached since 0.2385s ago] {'owner_pruduct_1': 'сляб'}
